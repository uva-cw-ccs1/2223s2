# %% [markdown]
# # Looking ahead
#
# Welcome to the final week of the course. This week we want to look ahead and focus on alternative ways to collect data and on infrastructure used for computational communication science.
#
#
# ### Scraping
#
# Last week you learned how to collect your own data using API's. However, not all websites have API's services available. In such cases, scraping is often a good solution.
#
# *In this course, we do not expect you to be able to scrape websites, but want to share it with you as a possibility for e.g., your thesis in the future.*

# %%
# 
from lxml import html
import requests

# %%
#Getting all restaurants
response = requests.get('https://cssbook.net/d/eat/index.html')

tree = html.fromstring(response.text)

# get get the names
cuisines = tree.xpath('/html/body/h2/text()')

# %%
type(cuisines)
# Out:
# list

# %%
#Getting real data
response = requests.get('https://www.politifact.com/factchecks/list/?ruling=true')

tree = html.fromstring(response.text)

# get get the names
names = tree.xpath('//*[@id="top"]/main/section[3]/article/section/div/article/ul/li/article/div[1]/div[2]/a/text()')

# %%
//*[@id="top"]/main/section[3]/article/section/div/article/ul/li[4]/article/div[1]/div[2]/a

# %%
names
# Out:
# ['\nTim Kaine\n',
#  '\nNikki Fried\n',
#  '\nKathy Hochul\n',
#  '\nGlenn Grothman\n',
#  '\nRobert Ortt\n',
#  '\nTed Cruz\n ',
#  '\nJohn Cornyn\n',
#  '\nJennifer McClellan\n',
#  '\nTony Evers\n',
#  '\nBrian Tyler Cohen\n',
#  '\nJoni Ernst\n',
#  '\nRoger Williams\n',
#  '\nJen Psaki\n',
#  '\nIowa Senate Democrats\n',
#  '\nNYS Department of Corrections and Community Supervision\n',
#  '\nCindy Axne\n',
#  '\nDavid Gura\n',
#  '\nKelda Helen Roys\n',
#  '\nRandy Feenstra\n',
#  '\nFacebook posts\n',
#  '\nMark Pocan\n',
#  '\nKathryn Moffett Bradford\n',
#  '\nDavid McKinley\n',
#  '\nChris Larson\n',
#  '\nMark Pocan\n',
#  '\nMitt Romney\n',
#  '\nMandela Barnes\n',
#  '\nViral image\n',
#  '\nCraig Thompson\n',
#  '\nGwen Moore\n']

# %%
response = requests.get('https://www.politifact.com/factchecks/list/?ruling=true')

tree = html.fromstring(response.text)

# get get the names
facts = tree.xpath('//*[@id="top"]/main/section[3]/article/section/div/article/ul/li/article/div[2]/div/div[1]/div/a/text()')

# %%
facts
# Out:
# ['\n“Virginia women are paid 80 cents for every dollar paid to Virginia men.”\n',
#  '\nFlorida is "49th in the nation when it comes to (Medicaid) funding” for people with disabilities.\n',
#  '\n“We are No. 1 among all large states in having fully vaccinated teenagers. We are No. 2 in all large states for having fully vaccinated five- to 11- year-olds.”\n',
#  '\n"The US has made strides in reducing carbon emissions that other parts of the world have not."\n',
#  '\n“With the ongoing pandemic, our State Park attendance is at the highest it’s ever been.”\n',
#  '\n"In 2020, more journalists were killed in Mexico than in any other country in the world."\n',
#  '\n"100,000 Americans died of an overdose in a single year."\n',
#  '\n“More than half of Virginia’s school buildings are older than 50 years.”\n',
#  '\nSays he has issued more pardons than “any Wisconsin governor in contemporary history.”\n',
#  '\n"Iowa Republicans have introduced a bill that would put government-installed cameras in every single classroom to livestream school activities for parents to spy on teachers and children."\n',
#  "\nIn Iowa, “since we have put a number of the voting laws into place over the last several years — voter ID is one of those — we've actually seen voter participation increase, even in off-election years.”\n",
#  '\n"The number of COVID-19 deaths recorded so far in 2021 has surpassed the total for 2020."\n',
#  '\n“You are 17 times more likely to go to the hospital if you’re not vaccinated, 20 times more likely to die.”\n',
#  '\nGov. Kim Reynolds, touting $210 million for Iowa broadband, “failed to mention these are actually federal funds approved by Rep. Cindy Axne and signed into law by President Joe Biden.”\n',
#  '\nNew York is "leading the nation with the lowest imprisonment rate of any large state”\n',
#  '\n“Iowa ranks 45th in the U.S. for internet connectivity."\n',
#  '\n“FUN FACT: West Virginia is home to zero billionaires.”\n',
#  '\nSays gubernatorial candidate Rebecca Kleefisch “worked with Scott Walker to sign five abortion restrictions into law that took away services and threatened doctors with prison time for providing safe and legal abortions.”\n',
#  '\nThe Biden administration "published a study concluding 4 (of) 5 new cars on the road by 2050 will still require liquid fuels."\n',
#  '\n"Southwest Airlines announce they will no longer terminate employees over the mandate."\n',
#  '\n“The annual Pentagon budget hovers over $750 billion annually, twice that of the much debated Build Back Better Act that costs about $350 billion annually as currently proposed.”\n',
#  '\n“If you look at the hospitalizations at Ruby Memorial in West Virginia, and around the country, 90% to 95% of those hospitalized are unvaccinated.”\n',
#  '\n“Overdose deaths in WV are up 45% from the prior year.”\n',
#  '\nThe GOP-controlled Legislature has "refused to act on at least 150" appointees of Gov. Tony Evers.\n',
#  '\n End of eviction moratorium means “millions of Americans” could lose their housing in the middle of a pandemic.\n',
#  '\nThe Trump administration worked to free 5,000 Taliban prisoners.\n',
#  '\nIn Afghanistan, “over 100 billion dollars spent on military contracts.”\n',
#  '\n\nA photo shows two COVID-19 patients lying on the floor awaiting treatment in Florida.\n',
#  '\n"We’ve got 115,000 miles of roads in this state and 90% is owned by the locals.”\n',
#  '\n“324,000 pregnant people experience domestic violence during their pregnancy.”\n']

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {'names': names,
     'facts': facts
    })

# %%
df
# Out:
#                                                 names  \
# 0                                       \nTim Kaine\n
# 1                                     \nNikki Fried\n
# 2                                    \nKathy Hochul\n
# 3                                  \nGlenn Grothman\n
# 4                                     \nRobert Ortt\n
# 5                                       \nTed Cruz\n
# 6                                     \nJohn Cornyn\n
# 7                              \nJennifer McClellan\n
# 8                                      \nTony Evers\n
# 9                               \nBrian Tyler Cohen\n
# 10                                     \nJoni Ernst\n
# 11                                 \nRoger Williams\n
# 12                                      \nJen Psaki\n
# 13                          \nIowa Senate Democrats\n
# 14  \nNYS Department of Corrections and Community ...
# 15                                     \nCindy Axne\n
# 16                                     \nDavid Gura\n
# 17                               \nKelda Helen Roys\n
# 18                                 \nRandy Feenstra\n
# 19                                 \nFacebook posts\n
# 20                                     \nMark Pocan\n
# 21                       \nKathryn Moffett Bradford\n
# 22                                 \nDavid McKinley\n
# 23                                   \nChris Larson\n
# 24                                     \nMark Pocan\n
# 25                                    \nMitt Romney\n
# 26                                 \nMandela Barnes\n
# 27                                    \nViral image\n
# 28                                 \nCraig Thompson\n
# 29                                     \nGwen Moore\n
#
#                                                 facts
# 0   \n“Virginia women are paid 80 cents for every ...
# 1   \nFlorida is "49th in the nation when it comes...
# 2   \n“We are No. 1 among all large states in havi...
# 3   \n"The US has made strides in reducing carbon ...
# 4   \n“With the ongoing pandemic, our State Park a...
# 5   \n"In 2020, more journalists were killed in Me...
# 6   \n"100,000 Americans died of an overdose in a ...
# 7   \n“More than half of Virginia’s school buildin...
# 8   \nSays he has issued more pardons than “any Wi...
# 9   \n"Iowa Republicans have introduced a bill tha...
# 10  \nIn Iowa, “since we have put a number of the ...
# 11  \n"The number of COVID-19 deaths recorded so f...
# 12  \n“You are 17 times more likely to go to the h...
# 13  \nGov. Kim Reynolds, touting $210 million for ...
# 14  \nNew York is "leading the nation with the low...
# 15  \n“Iowa ranks 45th in the U.S. for internet co...
# 16  \n“FUN FACT: West Virginia is home to zero bil...
# 17  \nSays gubernatorial candidate Rebecca Kleefis...
# 18  \nThe Biden administration "published a study ...
# 19  \n"Southwest Airlines announce they will no lo...
# 20  \n“The annual Pentagon budget hovers over $750...
# 21  \n“If you look at the hospitalizations at Ruby...
# 22  \n“Overdose deaths in WV are up 45% from the p...
# 23  \nThe GOP-controlled Legislature has "refused ...
# 24  \n End of eviction moratorium means “millions ...
# 25  \nThe Trump administration worked to free 5,00...
# 26  \nIn Afghanistan, “over 100 billion dollars sp...
# 27  \n\nA photo shows two COVID-19 patients lying ...
# 28  \n"We’ve got 115,000 miles of roads in this st...
# 29  \n“324,000 pregnant people experience domestic...
