# %% [markdown]
# # Data wrangling
#
# Welcome to the fourth week of the course. By the end of this week, you should acquire:
#
# **Knowledge on**:
#
# * Data wrangling principles and practices
# * Filtering, changing, grouping and joining data
# * The pandas package
#
#
# **Skills on**:
#
# * Data wrangling principles and practices
# * Filtering, changing, grouping and joining data
# * The pandas package

# %% [markdown]
# # Working with pandas

# %%
import pandas as pd
#Creating dataframes with pandas
data = [['tom', 10], ['nick', 15], ['juli', 14]]
df = pd.DataFrame(data, columns = ['Name', 'Age'])
df
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
#Importing data with pandas is incredibly easy
#Notice the sep argument, which stands for separator
apple_tweets = pd.read_csv("apple_tweets.csv", sep=",", encoding = 'unicode_escape')


#https://data.world/crowdflower/apple-twitter-sentiment

# %%
#Writing data with pandas is also very easy
dataset.to_csv("filename.csv", sep="....")

# %% [markdown]
# # Pickles are useful for writing tuples, lists and dicts, but can also read dataframes

# %%
import pickle
your_data = {'foo': 'bar'}
# Store data (serialize)
with open('filename.pickle', 'wb') as handle:
    pickle.dump(your_data, handle)

# Load data (deserialize)
with open('filename.pickle', 'rb') as handle:
    my_data = pickle.load(handle)

my_data
# Out:
# {'foo': 'bar'}

# %%
user_sessions=pd.read_pickle("user_sessions.pkl")
user_sessions
# Out:
#        session_id   session_timestamp  \
# 0      5555694754 2021-09-20 06:59:09
# 1      5555694755 2021-09-23 19:07:17
# 2      5555694756 2021-09-25 14:12:23
# 3      5555694757 2021-09-20 11:12:36
# 4      5555694758 2021-09-24 11:12:22
# ...           ...                 ...
# 49995  5555744749 2021-09-21 21:13:43
# 49996  5555744750 2021-09-20 05:27:21
# 49997  5555744751 2021-09-28 21:29:37
# 49998  5555744752 2021-09-25 19:33:29
# 49999  5555744753 2021-09-19 20:55:06
#
#                                               user_agent           referral  \
# 0      Mozilla/5.0 (Windows NT 6.2; lo-LA; rv:1.9.1.2...         google.com
# 1      Mozilla/5.0 (Windows; U; Windows NT 6.0) Apple...      instagram.com
# 2      Mozilla/5.0 (Android 2.3.6; Mobile; rv:7.0) Ge...      instagram.com
# 3      Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...         google.com
# 4      Opera/9.52.(X11; Linux i686; bho-IN) Presto/2....         google.com
# ...                                                  ...                ...
# 49995  Mozilla/5.0 (Macintosh; PPC Mac OS X 10 5_1 rv...  morales-patel.com
# 49996  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...          stark.com
# 49997  Mozilla/5.0 (Windows; U; Windows NT 6.1) Apple...      instagram.com
# 49998  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_1 like M...         google.com
# 49999  Mozilla/5.0 (Windows; U; Windows CE) AppleWebK...           webb.com
#
#        paid_campaign   user_id
# 0                1.0       NaN
# 1                4.0       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                2.0       NaN
# ...              ...       ...
# 49995            4.0       NaN
# 49996            1.0       NaN
# 49997            1.0  55886019
# 49998            NaN       NaN
# 49999            NaN  55886811
#
# [50000 rows x 6 columns]

# %% [markdown]
# # Wrangling 101

# %%
#Get a feel for your dataset 
apple_tweets.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  623495513     True      golden                  10               NaN
# 1  623495514     True      golden                  12               NaN
# 2  623495515     True      golden                  10               NaN
# 3  623495516     True      golden                  17               NaN
# 4  623495517    False   finalized                   3    12/12/14 12:14
#
#   sentiment  sentiment:confidence                            date  \
# 0         3                0.6264  Mon Dec 01 19:30:03 +0000 2014
# 1         3                0.8129  Mon Dec 01 19:43:51 +0000 2014
# 2         3                1.0000  Mon Dec 01 19:50:28 +0000 2014
# 3         3                0.5848  Mon Dec 01 20:26:34 +0000 2014
# 4         3                0.6474  Mon Dec 01 20:29:33 +0000 2014
#
#              id            query   sentiment_gold  \
# 0  5.400000e+17  #AAPL OR @Apple  3\nnot_relevant
# 1  5.400000e+17  #AAPL OR @Apple             3\n1
# 2  5.400000e+17  #AAPL OR @Apple                3
# 3  5.400000e+17  #AAPL OR @Apple             3\n1
# 4  5.400000e+17  #AAPL OR @Apple              NaN
#
#                                                 text
# 0  #AAPL:The 10 best Steve Jobs emails ever...htt...
# 1  RT @JPDesloges: Why AAPL Stock Had a Mini-Flas...
# 2  My cat only chews @apple cords. Such an #Apple...
# 3  I agree with @jimcramer that the #IndividualIn...
# 4       Nobody expects the Spanish Inquisition #AAPL

# %%
len(apple_tweets)
# Out:
# 3886

# %%
#print out all column names and see if there are any surprises
apple_tweets.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'sentiment', 'sentiment:confidence', 'date', 'id',
#        'query', 'sentiment_gold', 'text'],
#       dtype='object')

# %%
#Check column types 
apple_tweets.dtypes
# Out:
# _unit_id                  int64
# _golden                    bool
# _unit_state              object
# _trusted_judgments        int64
# _last_judgment_at        object
# sentiment                object
# sentiment:confidence    float64
# date                     object
# id                      float64
# query                    object
# sentiment_gold           object
# text                     object
# dtype: object

# %% [markdown]
# Notice above that last_judgement_at should really be a date of some kind, but it is not.

# %%
#Get a sense of the NA distribution in your dataset NaN
apple_tweets.isna().sum()
# Out:
# _unit_id                   0
# _golden                    0
# _unit_state                0
# _trusted_judgments         0
# _last_judgment_at        103
# sentiment                  0
# sentiment:confidence       0
# date                       0
# id                         0
# query                      0
# sentiment_gold          3783
# text                       0
# dtype: int64

# %%
#Drop missing values in a specific column
apple_tweets = apple_tweets.dropna(subset=["_last_judgment_at"])
apple_tweets.isna().sum()
# Out:
# _unit_id                   0
# _golden                    0
# _unit_state                0
# _trusted_judgments         0
# _last_judgment_at          0
# sentiment                  0
# sentiment:confidence       0
# date                       0
# id                         0
# query                      0
# sentiment_gold          3782
# text                       0
# dtype: int64

# %%
#Drop all missing values 
#apple_tweets = apple_tweets.dropna(how="any", inplace=True)

# %%
apple_tweets
# Out:
#        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 4     623495517    False   finalized                   3    12/12/14 12:14
# 9     623495522    False   finalized                   3     12/12/14 0:52
# 13    623495526    False   finalized                   3    12/12/14 21:38
# 15    623495528    False   finalized                   6    12/12/14 15:50
# 17    623495530    False   finalized                   3     12/12/14 3:38
# ...         ...      ...         ...                 ...               ...
# 3876  623499406    False   finalized                   3     12/12/14 2:08
# 3877  623499407    False   finalized                   3    12/11/14 20:08
# 3878  623499408    False   finalized                   3     12/12/14 3:32
# 3879  623499409    False   finalized                   6    12/11/14 20:50
# 3880  623499410    False   finalized                   3     12/12/14 2:58
#
#          sentiment  sentiment:confidence                            date  \
# 4                3                0.6474  Mon Dec 01 20:29:33 +0000 2014
# 9                3                0.6360  Mon Dec 01 20:45:03 +0000 2014
# 13               5                1.0000  Mon Dec 01 21:03:32 +0000 2014
# 15               3                0.4798  Mon Dec 01 21:29:45 +0000 2014
# 17    not_relevant                0.6904  Mon Dec 01 21:52:04 +0000 2014
# ...            ...                   ...                             ...
# 3876             3                1.0000  Tue Dec 09 21:21:12 +0000 2014
# 3877             1                1.0000  Tue Dec 09 21:23:33 +0000 2014
# 3878             5                0.6839  Tue Dec 09 21:24:22 +0000 2014
# 3879  not_relevant                0.6762  Tue Dec 09 21:27:06 +0000 2014
# 3880             1                0.6619  Tue Dec 09 21:28:07 +0000 2014
#
#                 id            query sentiment_gold  \
# 4     5.400000e+17  #AAPL OR @Apple            NaN
# 9     5.400000e+17  #AAPL OR @Apple            NaN
# 13    5.400000e+17  #AAPL OR @Apple            NaN
# 15    5.400000e+17  #AAPL OR @Apple            NaN
# 17    5.400000e+17  #AAPL OR @Apple            NaN
# ...            ...              ...            ...
# 3876  5.420000e+17  #AAPL OR @Apple            NaN
# 3877  5.420000e+17  #AAPL OR @Apple            NaN
# 3878  5.420000e+17  #AAPL OR @Apple            NaN
# 3879  5.420000e+17  #AAPL OR @Apple            NaN
# 3880  5.420000e+17  #AAPL OR @Apple            NaN
#
#                                                    text
# 4          Nobody expects the Spanish Inquisition #AAPL
# 9     #AAPL:This Presentation Shows What Makes The W...
# 13    RT @peterpham: Bought my @AugustSmartLock at t...
# 15    #aapl @applenws Thanks to the non factual dumb...
# 17    @Apple John Cantlie has been a prisoner of ISI...
# ...                                                 ...
# 3876  Apple Is Warming Up To Social Media: Apple is ...
# 3877  Being held hostage at @apple - They are replac...
# 3878  RT @shannonmmiller: Love the @Apple is support...
# 3879  Tim Cook Met With Jesse Jackson for 'Positive ...
# 3880  hey @apple is it normal for my laptop charger ...
#
# [3783 rows x 12 columns]

# %%
#Google .fillna() to get a sense of alternative approaches to dealing with NaN values

# %%
len(apple_tweets)
# Out:
# 3783

# %% [markdown]
# # Filtering, selecting and renaming
#
# Sometimes the dataset that you are working with contains lots of unncessery data. You will often want to filter (or subset) your dataset to include only:
# * some rows
# * some columns
# * some values

# %%
#Let's start with dropping some rows since this dataset is quite large for dealing with 
#The command below selects the first 5000 rows
#We can use the len function to check that our operation worked as expected
apple_tweets = apple_tweets[:100]
len(apple_tweets)
# Out:
# 100

# %%
#Remember that counting in Python starts at 0
apple_tweets = apple_tweets[0:50]
len(apple_tweets)
# Out:
# 50

# %%
#Sometimes we want to drop certain column because we will not need them
apple_tweets = apple_tweets.drop(columns=["_unit_id", "_golden"])
apple_tweets
#Notice the inplace approach to dropping columns in the book. Inplace can come in handy in many cases
# Out:
#    _unit_state  _trusted_judgments _last_judgment_at     sentiment  \
# 4    finalized                   3    12/12/14 12:14             3
#               query sentiment_gold  \
# 4   #AAPL OR @Apple            NaN
# 9   #AAPL OR @Apple            NaN
# 13  #AAPL OR @Apple            NaN
# 15  #AAPL OR @Apple            NaN
# 17  #AAPL OR @Apple            NaN
# 18  #AAPL OR @Apple            NaN
# 19  #AAPL OR @Apple            NaN
# 20  #AAPL OR @Apple            NaN
# 21  #AAPL OR @Apple            NaN
# 22  #AAPL OR @Apple            NaN
# 27  #AAPL OR @Apple            NaN
# 29  #AAPL OR @Apple            NaN
# 30  #AAPL OR @Apple            NaN
# 31  #AAPL OR @Apple            NaN
# 32  #AAPL OR @Apple            NaN
# 33  #AAPL OR @Apple            NaN
# 34  #AAPL OR @Apple            NaN
# 35  #AAPL OR @Apple            NaN
# 36  #AAPL OR @Apple            NaN
# 38  #AAPL OR @Apple            NaN
# 39  #AAPL OR @Apple            NaN
# 40  #AAPL OR @Apple            NaN
# 42  #AAPL OR @Apple            NaN
# 43  #AAPL OR @Apple            NaN
# 45  #AAPL OR @Apple            NaN
# 46  #AAPL OR @Apple            NaN
# 48  #AAPL OR @Apple            NaN
# 49  #AAPL OR @Apple            NaN
# 50  #AAPL OR @Apple            NaN
# 51  #AAPL OR @Apple            NaN
# 52  #AAPL OR @Apple            NaN
# 53  #AAPL OR @Apple            NaN
# 54  #AAPL OR @Apple            NaN
# 55  #AAPL OR @Apple            NaN
# 56  #AAPL OR @Apple            NaN
# 59  #AAPL OR @Apple            NaN
# 60  #AAPL OR @Apple            NaN
# 61  #AAPL OR @Apple            NaN
# 62  #AAPL OR @Apple            NaN
# 64  #AAPL OR @Apple            NaN
# 65  #AAPL OR @Apple            NaN
# 66  #AAPL OR @Apple            NaN
# 67  #AAPL OR @Apple            NaN
# 69  #AAPL OR @Apple            NaN
# 70  #AAPL OR @Apple            NaN
# 71  #AAPL OR @Apple            NaN
# 72  #AAPL OR @Apple            NaN
# 73  #AAPL OR @Apple            NaN
# 74  #AAPL OR @Apple            NaN
# 75  #AAPL OR @Apple            NaN
#
#                                                  text
# 4        Nobody expects the Spanish Inquisition #AAPL
# 9   #AAPL:This Presentation Shows What Makes The W...
# 13  RT @peterpham: Bought my @AugustSmartLock at t...
# 15  #aapl @applenws Thanks to the non factual dumb...
# 17  @Apple John Cantlie has been a prisoner of ISI...
# 18  @apple- thanks for xtra checkin at upper wests...
# 19  Why #AAPL Stock Had a Mini-Flash Crash Today: ...
# 20  $AAPL dip only momentarily....just an aberrati...
# 21  The JH Hines Staff with their newly issued @ap...
# 22  @robconeybeer: You need an IP portfolio to def...
# 27  Justice Department cites 18th century federal ...
# 29  RT @thehill: Justice Department cites 18th cen...
# 30  Good be huge RT @thehill Justice Department ci...
# 31  @thehill @Apple i cite the 4th amendment as a ...
# 32  RT @thehill: Justice Department cites 18th cen...
# 33  RT @saxonidubom: @rwang0 @Apple Thanks...think...
# 34  RT @thehill: Justice Department cites 18th cen...
# 35  Way to stay relevant RT @thehill: Justice Depa...
# 36  Apple Inc. Flash Crash: What You Need to Know ...
# 38  RT @thehill: Justice Department cites 18th cen...
# 39  That flash crash really screwed with a lot of ...
# 40  RT @tra_hall: The JH Hines Staff with their ne...
# 42  RT @thehill: Justice Department cites 18th cen...
# 43  RT @thehill: Justice Department cites 18th cen...
# 45  RT @thehill: Justice Department cites 18th cen...
# 46  @thehill @Apple I cite the us constitution whe...
# 48  @thehill @Apple Wish we could prosecute the ad...
# 49  RT @thehill: Justice Department cites 18th cen...
# 50  @thehill @Apple Furthermore there are no provi...
# 51  #AAPL:Here's why Apple dropped...http://t.co/q...
# 52  This one chart explains @tim_cook's affect on ...
# 53  RT @thehill: Justice Department cites 18th cen...
# 54  RT @thehill: Justice Department cites 18th cen...
# 55  Final #AAPL #PutCallRatios for Monday, Decembe...
# 56  #AAPL Launches Red #Apple Logo for World AIDS ...
# 59  @apple why doesn't your people explain precaut...
# 60  RT @thehill: Justice Department cites 18th cen...
# 61                  @Quailman_ @Apple u was bored huh
# 62  RT @wagner_tim: @robconeybeer: You need an IP ...
# 64  @Apple made it clear today that I as a custome...
# 65  INSPI(RED) by @Apple and @tim_cook on #WorldAI...
# 66  RT @thehill: Justice Department cites 18th cen...
# 67  16GB @Apple #iPad Air 2 Retina WiFi Tablet $40...
# 69  Why does @Apple force people to use its VPN bu...
# 70  Then how the hell did I take this screenshot? ...
# 71  RT @thehill Department cites 18th century fede...
# 72  RT @thehill: Justice Department cites 18th cen...
# 73  Buy round lot on the open MT @WSJD #AAPL stock...
# 74          3G is draining my battery fix this @apple
# 75  My daughter's @Apple #iPod stolen. To the thie...

# %%
#We can alterntively choose which columns to keep
apple_tweets = apple_tweets[["_unit_state", "_trusted_judgments", "sentiment", "date", "id", "query", "text"]]
apple_tweets.columns
# Out:
# Index(['_unit_state', '_trusted_judgments', 'sentiment', 'date', 'id', 'query',
#        'text'],
#       dtype='object')

# %%
apple_tweets
# Out:
#    _unit_state  _trusted_judgments     sentiment  \
# 4    finalized                   3             3
# 9    finalized                   3             3
# 13   finalized                   3             5
# 15   finalized                   6             3
# 17   finalized                   3  not_relevant
# 18   finalized                   3             3
# 19   finalized                   3             3
# 20   finalized                   3  not_relevant
# 21   finalized                   4             3
# 22   finalized                   3             3
# 27   finalized                   4             3
# 29   finalized                   3             3
# 30   finalized                   4             3
# 31   finalized                   3             3
# 32   finalized                   3             3
# 33   finalized                   4             5
# 34   finalized                   3             3
# 35   finalized                   3             3
# 36   finalized                   6             3
# 38   finalized                   3             3
# 39   finalized                   6             1
# 40   finalized                   3             3
# 42   finalized                   3             3
# 43   finalized                   3             1
# 45   finalized                   3             3
# 46   finalized                   6             1
# 48   finalized                   3             1
# 49   finalized                   3             3
# 50   finalized                   3             3
# 51   finalized                   3             1
# 52   finalized                   4             3
# 53   finalized                   3             3
# 54   finalized                   3             3
# 55   finalized                   4             3
# 56   finalized                   3             3
# 59   finalized                   3             1
# 60   finalized                   3             3
# 61   finalized                   3             3
# 62   finalized                   3             3
# 64   finalized                   3             1
# 65   finalized                   3             3
# 66   finalized                   4             3
# 67   finalized                   3             3
# 69   finalized                   3             1
# 70   finalized                   3             1
# 71   finalized                   3             3
# 72   finalized                   3             3
# 73   finalized                   6             1
# 74   finalized                   3             1
# 75   finalized                   3  not_relevant
#
#                               date            id            query  \
# 4   Mon Dec 01 20:29:33 +0000 2014  5.400000e+17  #AAPL OR @Apple
#
# 38  RT @thehill: Justice Department cites 18th cen...
# 39  That flash crash really screwed with a lot of ...
# 40  RT @tra_hall: The JH Hines Staff with their ne...
# 42  RT @thehill: Justice Department cites 18th cen...
# 43  RT @thehill: Justice Department cites 18th cen...
# 45  RT @thehill: Justice Department cites 18th cen...
# 46  @thehill @Apple I cite the us constitution whe...
# 48  @thehill @Apple Wish we could prosecute the ad...
# 49  RT @thehill: Justice Department cites 18th cen...
# 50  @thehill @Apple Furthermore there are no provi...
# 51  #AAPL:Here's why Apple dropped...http://t.co/q...
# 52  This one chart explains @tim_cook's affect on ...
# 53  RT @thehill: Justice Department cites 18th cen...
# 54  RT @thehill: Justice Department cites 18th cen...
# 55  Final #AAPL #PutCallRatios for Monday, Decembe...
# 56  #AAPL Launches Red #Apple Logo for World AIDS ...
# 59  @apple why doesn't your people explain precaut...
# 60  RT @thehill: Justice Department cites 18th cen...
# 61                  @Quailman_ @Apple u was bored huh
# 62  RT @wagner_tim: @robconeybeer: You need an IP ...
# 64  @Apple made it clear today that I as a custome...
# 65  INSPI(RED) by @Apple and @tim_cook on #WorldAI...
# 66  RT @thehill: Justice Department cites 18th cen...
# 67  16GB @Apple #iPad Air 2 Retina WiFi Tablet $40...
# 69  Why does @Apple force people to use its VPN bu...
# 70  Then how the hell did I take this screenshot? ...
# 71  RT @thehill Department cites 18th century fede...
# 72  RT @thehill: Justice Department cites 18th cen...
# 73  Buy round lot on the open MT @WSJD #AAPL stock...
# 74          3G is draining my battery fix this @apple
# 75  My daughter's @Apple #iPod stolen. To the thie...

# %%
apple_tweets.dtypes
# Out:
# _unit_state            object
# _trusted_judgments      int64
# sentiment              object
# date                   object
# id                    float64
# query                  object
# text                   object
# dtype: object

# %%
#To do that we may need to change the column type 
apple_tweets["_trusted_judgments"] = apple_tweets["_trusted_judgments"].astype(int)

#Note that when subsetting with multiple conditions, we must use the & operator
apple_tweets = apple_tweets[(apple_tweets["_trusted_judgments"] > 4) & (apple_tweets["sentiment"] != "not_relevant")]
apple_tweets.sort_values(by=["_trusted_judgments"], ascending=False)
apple_tweets
# Out:
#    _unit_state  _trusted_judgments sentiment                            date  \
# 15   finalized                   6         3  Mon Dec 01 21:29:45 +0000 2014
# 36   finalized                   6         3  Tue Dec 02 00:22:31 +0000 2014
# 39   finalized                   6         1  Tue Dec 02 00:24:47 +0000 2014
# 46   finalized                   6         1  Tue Dec 02 00:32:42 +0000 2014
# 73   finalized                   6         1  Tue Dec 02 01:25:49 +0000 2014
#
#               id            query  \
# 15  5.400000e+17  #AAPL OR @Apple
# 36  5.400000e+17  #AAPL OR @Apple
# 39  5.400000e+17  #AAPL OR @Apple
# 46  5.400000e+17  #AAPL OR @Apple
# 73  5.400000e+17  #AAPL OR @Apple
#
#                                                  text
# 15  #aapl @applenws Thanks to the non factual dumb...
# 36  Apple Inc. Flash Crash: What You Need to Know ...
# 39  That flash crash really screwed with a lot of ...
# 46  @thehill @Apple I cite the us constitution whe...
# 73  Buy round lot on the open MT @WSJD #AAPL stock...

# %%
apple_tweets.head(60)
# Out:
#    _unit_state  _trusted_judgments sentiment                            date  \
# 15   finalized                   6         3  Mon Dec 01 21:29:45 +0000 2014
# 36   finalized                   6         3  Tue Dec 02 00:22:31 +0000 2014
# 39   finalized                   6         1  Tue Dec 02 00:24:47 +0000 2014
# 46   finalized                   6         1  Tue Dec 02 00:32:42 +0000 2014
# 73   finalized                   6         1  Tue Dec 02 01:25:49 +0000 2014
#
#               id            query  \
# 15  5.400000e+17  #AAPL OR @Apple
# 36  5.400000e+17  #AAPL OR @Apple
# 39  5.400000e+17  #AAPL OR @Apple
# 46  5.400000e+17  #AAPL OR @Apple
# 73  5.400000e+17  #AAPL OR @Apple
#
#                                                  text
# 15  #aapl @applenws Thanks to the non factual dumb...
# 36  Apple Inc. Flash Crash: What You Need to Know ...
# 39  That flash crash really screwed with a lot of ...
# 46  @thehill @Apple I cite the us constitution whe...
# 73  Buy round lot on the open MT @WSJD #AAPL stock...

# %%
#Sometimes we may only want to keep rows with certain values 
apple_tweets['text'] = apple_tweets['text'].astype('str')
apple_tweets = apple_tweets[apple_tweets['text'].str.len() > 20]
apple_tweets
# Out:
#    _unit_state  _trusted_judgments sentiment                            date  \
# 15   finalized                   6         3  Mon Dec 01 21:29:45 +0000 2014
# 36   finalized                   6         3  Tue Dec 02 00:22:31 +0000 2014
# 39   finalized                   6         1  Tue Dec 02 00:24:47 +0000 2014
# 46   finalized                   6         1  Tue Dec 02 00:32:42 +0000 2014
# 73   finalized                   6         1  Tue Dec 02 01:25:49 +0000 2014
#
#               id            query  \
# 15  5.400000e+17  #AAPL OR @Apple
# 36  5.400000e+17  #AAPL OR @Apple
# 39  5.400000e+17  #AAPL OR @Apple
# 46  5.400000e+17  #AAPL OR @Apple
# 73  5.400000e+17  #AAPL OR @Apple
#
#                                                  text
# 15  #aapl @applenws Thanks to the non factual dumb...
# 36  Apple Inc. Flash Crash: What You Need to Know ...
# 39  That flash crash really screwed with a lot of ...
# 46  @thehill @Apple I cite the us constitution whe...
# 73  Buy round lot on the open MT @WSJD #AAPL stock...

# %%
#Renaming columns 
apple_tweets.rename({'_unit_state': 'unit_state', '_trusted_judgments': 'trusted_judgements'}, axis='columns', inplace=True)
apple_tweets
# Out:
#        _unit_id  _golden unit_state  trusted_judgements _last_judgment_at  \
# 0     623495513     True     golden                  10               NaN
# 1     623495514     True     golden                  12               NaN
# 2     623495515     True     golden                  10               NaN
# 3     623495516     True     golden                  17               NaN
# 4     623495517    False  finalized                   3    12/12/14 12:14
# ...         ...      ...        ...                 ...               ...
# 3881  623499442     True     golden                  13               NaN
# 3882  623499450     True     golden                  16               NaN
# 3883  623499486     True     golden                  14               NaN
# 3884  623499514     True     golden                  13               NaN
# 3885  623517290     True     golden                  17               NaN
#
#      sentiment  sentiment:confidence                            date  \
# 0            3                0.6264  Mon Dec 01 19:30:03 +0000 2014
# 1            3                0.8129  Mon Dec 01 19:43:51 +0000 2014
# 2            3                1.0000  Mon Dec 01 19:50:28 +0000 2014
# 3            3                0.5848  Mon Dec 01 20:26:34 +0000 2014
# 4            3                0.6474  Mon Dec 01 20:29:33 +0000 2014
# ...        ...                   ...                             ...
# 3881         3                0.7757  Tue Dec 09 22:08:53 +0000 2014
# 3882         3                0.6225  Tue Dec 09 22:18:27 +0000 2014
# 3883         5                0.9347  Tue Dec 09 23:45:59 +0000 2014
# 3884         1                0.9230  Wed Dec 10 00:48:10 +0000 2014
# 3885         5                0.8938  Tue Dec 09 09:01:25 +0000 2014
#
#                 id            query      sentiment_gold  \
# 0     5.400000e+17  #AAPL OR @Apple     3\nnot_relevant
# 1     5.400000e+17  #AAPL OR @Apple                3\n1
# 2     5.400000e+17  #AAPL OR @Apple                   3
# 3     5.400000e+17  #AAPL OR @Apple                3\n1
# 4     5.400000e+17  #AAPL OR @Apple                 NaN
# ...            ...              ...                 ...
# 3881  5.420000e+17  #AAPL OR @Apple                5\n3
# 3882  5.420000e+17  #AAPL OR @Apple                3\n1
# 3883  5.420000e+17  #AAPL OR @Apple                   5
# 3884  5.420000e+17  #AAPL OR @Apple                   1
# 3885  5.420000e+17  #AAPL OR @Apple  5\n3\nnot_relevant
#
#                                                    text
# 0     #AAPL:The 10 best Steve Jobs emails ever...htt...
# 1     RT @JPDesloges: Why AAPL Stock Had a Mini-Flas...
# 2     My cat only chews @apple cords. Such an #Apple...
# 3     I agree with @jimcramer that the #IndividualIn...
# 4          Nobody expects the Spanish Inquisition #AAPL
# ...                                                 ...
# 3881  (Via FC) Apple Is Warming Up To Social Media -...
# 3882  RT @MMLXIV: there is no avocado emoji may I as...
# 3883  @marcbulandr I could not agree more. Between @...
# 3884  My iPhone 5's photos are no longer downloading...
# 3885  RT @SwiftKey: We're so excited to be named to ...
#
# [3886 rows x 12 columns]

# %%
#grouping
#apple_tweets['trusted_judgements'] = apple_tweets['trusted_judgements'].astype("int64")
#apple_tweets.groupby(['unit_state'])['trusted_judgements'].std()
apple_tweets.groupby(['unit_state', 'date']).size()
# Out:
# unit_state  date
# finalized   Fri Dec 05 00:02:35 +0000 2014    1
#             Fri Dec 05 00:02:59 +0000 2014    1
#             Fri Dec 05 00:04:39 +0000 2014    1
#             Fri Dec 05 00:04:41 +0000 2014    1
#             Fri Dec 05 00:05:43 +0000 2014    1
#                                              ..
# golden      Wed Dec 03 19:44:55 +0000 2014    1
#             Wed Dec 03 22:01:20 +0000 2014    1
#             Wed Dec 03 22:15:03 +0000 2014    1
#             Wed Dec 03 23:03:02 +0000 2014    1
#             Wed Dec 10 00:48:10 +0000 2014    1
# Length: 3797, dtype: int64

# %%
#aggregating
pd.options.display.float_format = '{:.2f}'.format
apple_tweets['sentiment'] = apple_tweets['sentiment'].astype("int64")
apple_tweets.agg({"sentiment": ["mean", "median", "std"]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6j/8lr60c9j22scx8r2ww_dtv2c0000gn/T/ipykernel_43341/3535757592.py in <module>
#       1 #aggregating
#       2 pd.options.display.float_format = '{:.2f}'.format
# ----> 3 apple_tweets['sentiment'] = apple_tweets['sentiment'].astype("int64")
#       4 apple_tweets.agg({"sentiment": ["mean", "median", "std"]})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'not_relevant'

# %% [markdown]
# # Book wrangling snippet

# %%
url="https://cssbook.net/d/guns-polls-dirty.csv"
d2=pd.read_csv(url)

# Option 1: clean with direct assignment
# Note that when creating a new column, 
# you have to use df["col"] rather than df.col 
d2["rep2"] = d2.rep.str.replace("[^0-9\\.]", "")
d2["rep2"] = pd.to_numeric(d2.rep2)
d2["Support2"]=d2.Support.fillna(d.Support.mean())

# Alternatively, clean with .assign 
# Note the need to use an anonymous function
# (lambda) to chain calculations
cleaned = d2.assign(
    rep2 = d2.rep.str.replace("[^0-9\\.]", ""),
    rep3 = lambda d2: pd.to_numeric(d2.rep2),
    Support2=d2.Support.fillna(d2.Support.mean()))


# Finally, you can create your own function 
def clean_num(x):
    x = re.sub("[^0-9\\.]", "", x)
    return int(x)

cleaned["rep3"] = cleaned.rep.apply(clean_num)
cleaned.head()

# %% [markdown]
# # Merging

# %%
apple_1 = pd.read_csv("apple_1.csv", sep=";")

# %%
apple_2 = pd.read_csv("apple_2.csv", sep=";")

# %%
apple_1.columns
# Out:
# Index(['_unit_id', 'unit_state'], dtype='object')

# %%
apple_2.columns
# Out:
# Index(['unit_id', '_golden', '_trusted_judgments', '_last_judgment_at',
#        'sentiment', 'sentiment:confidence', 'date', 'id', 'query',
#        'sentiment_gold', 'text'],
#       dtype='object')

# %%
#Merging on a column of the same dataset
#This will not run for these datasets. 
full = pd.merge(apple_1, apple_2, how="inner", on="unit_id")

# %%
#Merging on two or more columns with the same name across both datasets
#This will not run for these datasets
full = pd.merge(apple_1, apple_2, how="inner", on=['column1', 'column2'])

# %%
#Merging on different keys - left
full = pd.merge(apple_1, apple_2, how="left", left_on='_unit_id', right_on='unit_id')

#We will need this line to merge succesfully 
#apple_2['unit_id'] = pd.to_numeric(apple_2['unit_id'], errors='coerce')

# %%
#Merging on different keys - right
full = pd.merge(apple_1, apple_2, how="right", left_on='_unit_id', right_on='unit_id')

# %%
#Merging on different keys - outer
full = pd.merge(apple_1, apple_2, how="outer", left_on='_unit_id', right_on='unit_id')

# %%
#Merging on different keys - inner
full = pd.merge(apple_1, apple_2, how="inner", left_on='_unit_id', right_on='unit_id')

# %%
#Concatenating 
apple_3 = pd.read_csv("apple_3.csv", sep=';')
apple_4 = pd.read_csv("apple_4.csv", sep=';')

full = pd.concat([apple_3, apple_4])
len(apple_3)

# %%
len(apple_4)

# %%
#len(full) = len(apple_3) + (apple_4)
len(full)
