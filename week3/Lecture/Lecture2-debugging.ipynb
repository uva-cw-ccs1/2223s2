# %% [markdown]
# # Handling errors
#
# In order to make errors your friends, avoid getting stuck and use them to improve and further your code, try to understand:
# * What is the *type* of error you are getting?
# * *Where* is this error happening?

# %%
df = pd.read_csv('Example_shop_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ba986aac270> in <module>
# ----> 1 df = pd.read_csv('Example_shop_data.csv')
#
# NameError: name 'pd' is not defined

# %%
from guizero import App, Text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-38a993cb4bed> in <module>
# ----> 1 from guizero import App, Text
#
# ModuleNotFoundError: No module named 'guizero'

# %%
a = 1
b = 1000000

if a > b: 
    print('a > b')
elif a < b: 
    print('a < b')
elif a = b: 
    print('a == b')
# Out:
#   File "<ipython-input-10-b5fe470e3bec>", line 8
#     elif a = b:
#            ^
# SyntaxError: invalid syntax

# %%
x = 5
list(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a94aa89155fe> in <module>
#       1 x = 5
# ----> 2 list(x)
#
# TypeError: 'int' object is not iterable

# %%
tweets=['Microsoft flying high in BI & Analytics - Based on Gartner Research #DigitalTransformation #digital #intelligence #BI #AI #crm #erp https://t.co/34CiKD7GKi',
       'CustomerDevoted,"Sentiment analysis in the age of Digital Transformation | #BigData #Analytics #RT https://t.co/zGmXGMpz6k by #Ronald_vanLoon https://t.co/vTjLsmbarr',
       'Eyeview Digital - Manager, Client Analytics - Chicago  #tech #Manager #Client #Analytics #Chicago https://t.co/9aBzOfrZ6n',
       'Leading Digital Marketing Company Eminent Infoweb Introduces Web Analytics Services https://t.co/iI0tSXu00n',
       'RT @JimMarous: Top Areas of #Martech Investments  #DigitalMarketing #socialmedia #Marketing #analytics #digital #CX… https://t.co/AlGzTjW5qB', None,
       'Leading Digital Marketing Company Eminent Infoweb Introduces Web Analytics Services https://t.co/GYkbyxJnyC',
       '#sprkyfeed Loom Systems Helps Digital Businesses Solve Issues Through AI-Powered Operational Analytics ... https://t.co/luweP17Efo #AI']

# %%
def count_hashtag(text):
    print(text)
    counter = 0
    try:
        for char in text:
            print(char)
            if char == '#':
                counter += 1
    except:
        print("ERROR")
    return counter

# %%
count_hashtag('CustomerDevoted,"Sentiment analysis in the age of Digital Transformation | #BigData')
# Out:
# CustomerDevoted,"Sentiment analysis in the age of Digital Transformation | #BigData
# C
# u
# s
# t
# o
# m
# e
# r
# D
# e
# v
# o
# t
# e
# d
# ,
# "
# S
# e
# n
# t
# i
# m
# e
# n
# t
#
# a
# n
# a
# l
# y
# s
# i
# s
#
# i
# n
#
# t
# h
# e
#
# a
# g
# e
#
# o
# f
#
# D
# i
# g
# i
# t
# a
# l
#
# T
# r
# a
# n
# s
# f
# o
# r
# m
# a
# t
# i
# o
# n
#
# |
#
# #
# B
# i
# g
# D
# a
# t
# a
# 1

# %%
for tweet in tweets:
    print(count_hashtag(tweet))
# Out:
# Microsoft flying high in BI & Analytics - Based on Gartner Research #DigitalTransformation #digital #intelligence #BI #AI #crm #erp https://t.co/34CiKD7GKi
# M
# i
# c
# r
# o
# s
# o
# f
# t
#
# f
# l
# y
# i
# n
# g
#
# h
# i
# g
# h
#
# i
# n
#
# B
# I
#
# &
#
# A
# n
# a
# l
# y
# t
# i
# c
# s
#
# -
#
# B
# a
# s
# e
# d
#
# o
# n
#
# G
# a
# r
# t
# n
# e
# r
#
# R
# e
# s
# e
# a
# r
# c
# h
#
# #
# D
# i
# g
# i
# t
# a
# l
# T
# r
# a
# n
# s
# f
# o
# r
# m
# a
# t
# i
# o
# n
#
# #
# d
# i
# g
# i
# t
# a
# l
#
# #
# i
# n
# t
# e
# l
# l
# i
# g
# e
# n
# c
# e
#
# #
# B
# I
#
# #
# A
# I
#
# #
# c
# r
# m
#
# #
# e
# r
# p
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# 3
# 4
# C
# i
# K
# D
# 7
# G
# K
# i
# 7
# CustomerDevoted,"Sentiment analysis in the age of Digital Transformation | #BigData #Analytics #RT https://t.co/zGmXGMpz6k by #Ronald_vanLoon https://t.co/vTjLsmbarr
# C
# u
# s
# t
# o
# m
# e
# r
# D
# e
# v
# o
# t
# e
# d
# ,
# "
# S
# e
# n
# t
# i
# m
# e
# n
# t
#
# a
# n
# a
# l
# y
# s
# i
# s
#
# i
# n
#
# t
# h
# e
#
# a
# g
# e
#
# o
# f
#
# D
# i
# g
# i
# t
# a
# l
#
# T
# r
# a
# n
# s
# f
# o
# r
# m
# a
# t
# i
# o
# n
#
# |
#
# #
# B
# i
# g
# D
# a
# t
# a
#
# #
# A
# n
# a
# l
# y
# t
# i
# c
# s
#
# #
# R
# T
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# z
# G
# m
# X
# G
# M
# p
# z
# 6
# k
#
# b
# y
#
# #
# R
# o
# n
# a
# l
# d
# _
# v
# a
# n
# L
# o
# o
# n
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# v
# T
# j
# L
# s
# m
# b
# a
# r
# r
# 4
# Eyeview Digital - Manager, Client Analytics - Chicago  #tech #Manager #Client #Analytics #Chicago https://t.co/9aBzOfrZ6n
# E
# y
# e
# v
# i
# e
# w
#
# D
# i
# g
# i
# t
# a
# l
#
# -
#
# M
# a
# n
# a
# g
# e
# r
# ,
#
# C
# l
# i
# e
# n
# t
#
# A
# n
# a
# l
# y
# t
# i
# c
# s
#
# -
#
# C
# h
# i
# c
# a
# g
# o
#
#
# #
# t
# e
# c
# h
#
# #
# M
# a
# n
# a
# g
# e
# r
#
# #
# C
# l
# i
# e
# n
# t
#
# #
# A
# n
# a
# l
# y
# t
# i
# c
# s
#
# #
# C
# h
# i
# c
# a
# g
# o
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# 9
# a
# B
# z
# O
# f
# r
# Z
# 6
# n
# 5
# Leading Digital Marketing Company Eminent Infoweb Introduces Web Analytics Services https://t.co/iI0tSXu00n
# L
# e
# a
# d
# i
# n
# g
#
# D
# i
# g
# i
# t
# a
# l
#
# M
# a
# r
# k
# e
# t
# i
# n
# g
#
# C
# o
# m
# p
# a
# n
# y
#
# E
# m
# i
# n
# e
# n
# t
#
# I
# n
# f
# o
# w
# e
# b
#
# I
# n
# t
# r
# o
# d
# u
# c
# e
# s
#
# W
# e
# b
#
# A
# n
# a
# l
# y
# t
# i
# c
# s
#
# S
# e
# r
# v
# i
# c
# e
# s
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# i
# I
# 0
# t
# S
# X
# u
# 0
# 0
# n
# 0
# RT @JimMarous: Top Areas of #Martech Investments  #DigitalMarketing #socialmedia #Marketing #analytics #digital #CX… https://t.co/AlGzTjW5qB
# R
# T
#
# @
# J
# i
# m
# M
# a
# r
# o
# u
# s
# :
#
# T
# o
# p
#
# A
# r
# e
# a
# s
#
# o
# f
#
# #
# M
# a
# r
# t
# e
# c
# h
#
# I
# n
# v
# e
# s
# t
# m
# e
# n
# t
# s
#
#
# #
# D
# i
# g
# i
# t
# a
# l
# M
# a
# r
# k
# e
# t
# i
# n
# g
#
# #
# s
# o
# c
# i
# a
# l
# m
# e
# d
# i
# a
#
# #
# M
# a
# r
# k
# e
# t
# i
# n
# g
#
# #
# a
# n
# a
# l
# y
# t
# i
# c
# s
#
# #
# d
# i
# g
# i
# t
# a
# l
#
# #
# C
# X
# …
#
# h
# t
# t
# p
# s
# :
# /
# /
# t
# .
# c
# o
# /
# A
# l
# G
# z
# T
# j
# W
# 5
# q
# B
# 7
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-3e1d6a4f7105> in <module>
#       1 for tweet in tweets:
# ----> 2     print(count_hashtag(tweet))
#
# <ipython-input-2-b8da335aa349> in count_hashtag(text)
#       2     print(text)
#       3     counter = 0
# ----> 4     for char in text:
#       5         print(char)
#       6         if char == '#':
#
# TypeError: 'NoneType' object is not iterable
