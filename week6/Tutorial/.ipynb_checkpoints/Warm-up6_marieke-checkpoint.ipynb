# %% [markdown]
# # Warm-up excercises week 6
#
# Now that you have seen how to communicate with basic APIs, it's time for you to combine apply this knowledge. To prepare for the tutorial, we ask you to complete two warm-up excercises.
#
#
# Some important notes for the excercises:
#
# * These excercises are a warming up meant to help you get ready for class. Make sure to give them a try on all of them. If you get an error message, try to troubleshoot it (using Google often helps). If all else fails, go to the next excercise (but make sure to hand it in).
# * While we of course like when you get all the answers right, the important thing is to exercise and apply the knowledge. So we will still accept solutions that may not be complete, as long as we see enough effort for each excercise.
# * Delivering the warm-up excercises on time is critical, as it helps also prepare for the tutorial session.
# * As these excercises are meant to help you participate in the tutorial and us to make sure you can get as much as possible from the tutorials, we do not expect perfect answers. However, this is important to show the effort you have put in the excercises and what obstacles you faced.

# %%
import requests # needed to interact with APIs
import json
import pandas as pd

# %%
requests?
# Out:
# Type:        module
# String form: <module 'requests' from '/Users/marieke/Library/Python/3.8/lib/python/site-packages/requests/__init__.py'>
# File:        ~/Library/Python/3.8/lib/python/site-packages/requests/__init__.py
# Docstring:
# Requests HTTP Library
# ~~~~~~~~~~~~~~~~~~~~~
#
# Requests is an HTTP library, written in Python, for human beings.
# Basic GET usage:
#
#    >>> import requests
#    >>> r = requests.get('https://www.python.org')
#    >>> r.status_code
#    200
#    >>> b'Python is a programming language' in r.content
#    True
#
# ... or POST:
#
#    >>> payload = dict(key1='value1', key2='value2')
#    >>> r = requests.post('https://httpbin.org/post', data=payload)
#    >>> print(r.text)
#    {
#      ...
#      "form": {
#        "key1": "value1",
#        "key2": "value2"
#      },
#      ...
#    }
#
# The other HTTP methods are supported - see `requests.api`. Full documentation
# is at <https://requests.readthedocs.io>.
#
# :copyright: (c) 2017 by Kenneth Reitz.
# :license: Apache 2.0, see LICENSE for more details.

# %% [markdown]
# # Excercise 1
#
# 1. During the lecture, we broke down our interaction with the datamuse API. The documentation for this API is available here https://www.datamuse.com/api/. Use another operation discussed in class  offered by this API apart from the ones we interacted with in the lecture.
# 2. Explain the meaning of the http response code you received.
# 3. Some of the endpoint return values which allow you to subset your data. For instance, rel_rhy return the rhyming word, as well as it's "rhyming score". We could use the rhyming score to create a dataframe with only the most "strongly rhyming words". Get a part of your data (API response) into a dataframe based on criteria of your choosing.

# %%
# Choose suggestions (sug) as endpoint
parameter = {"s":"comp"} # string I want to find suggestions for is "comp"
r = requests.get('https://api.datamuse.com/sug', parameter)

# %%
# alternatively:
r = requests.get('https://api.datamuse.com/sug?s=comp')
r.json()
# Out:
# [{'word': 'company', 'score': 4152},
#  {'word': 'complement', 'score': 3601},
#  {'word': 'complex', 'score': 3513},
#  {'word': 'compromise', 'score': 3318},
#  {'word': 'compound', 'score': 3108},
#  {'word': 'comprehensive', 'score': 3060},
#  {'word': 'comprise', 'score': 2987},
#  {'word': 'compliment', 'score': 2718},
#  {'word': 'computer', 'score': 2584},
#  {'word': 'complicit', 'score': 2552}]

# %%
# This worked, response code 200 = OK!
r
# Out:
# <Response [200]>

# %%
# why is computational not a suggestion!!
r.json()
# Out:
# [{'word': 'company', 'score': 4152},
#  {'word': 'complement', 'score': 3601},
#  {'word': 'complex', 'score': 3513},
#  {'word': 'compromise', 'score': 3318},
#  {'word': 'compound', 'score': 3108},
#  {'word': 'comprehensive', 'score': 3060},
#  {'word': 'comprise', 'score': 2987},
#  {'word': 'compliment', 'score': 2718},
#  {'word': 'computer', 'score': 2584},
#  {'word': 'complicit', 'score': 2552}]

# %%
# Choose words as endpoint and specify multiple parameters
# words associated with "student", return max 10, return meta data (definition and Part of Speech tag)
parameter = {"rel_trg":"student", "max":10, "md":"p d"} 
r = requests.get('https://api.datamuse.com/words', parameter)
r # all went well
# Out:
# <Response [200]>

# %%
# this makes the string: 'https://api.datamuse.com/words?rel_trg=student&max=10&md=p%20%d'

# %%
r.json()
# Out:
# [{'word': 'enrollment',
#   'score': 1347,
#   'tags': ['n'],
#   'defs': ['n\tthe act of enrolling',
#    'n\tthe body of people (such as students) who register or enroll at the same time']},
#  {'word': 'tuition',
#   'score': 1321,
#   'tags': ['n'],
#   'defs': ['n\ta fee paid for instruction (especially for higher education)',
#    'n\tteaching pupils individually (usually by a tutor hired privately)']},
#  {'word': 'ratio',
#   'score': 1319,
#   'tags': ['n'],
#   'defs': ['n\tthe relative magnitudes of two quantities (usually expressed as a quotient)']},
#  {'word': 'achievement',
#   'score': 1310,
#   'tags': ['n'],
#   'defs': ['n\tthe action of accomplishing something']},
#  {'word': 'math',
#   'score': 1306,
#   'tags': ['n'],
#   'defs': ['n\ta science (or group of related sciences) dealing with the logic of quantity and shape and arrangement']},
#  {'word': 'eligible',
#   'score': 1292,
#   'tags': ['adj'],
#   'defs': ['adj\tprohibited by official rules',
#    'adj\tqualified for or allowed or worthy of being chosen']},
#  {'word': 'loans',
#   'score': 1289,
#   'tags': ['n'],
#   'defs': ['n\tthe temporary provision of money (usually at interest)',
#    "n\ta word borrowed from another language; e.g. `blitz' is a German word borrowed into modern English"],
#   'defHeadword': 'loan'},
#  {'word': 'teacher',
#   'score': 1285,
#   'tags': ['n'],
#   'defs': ['n\ta personified abstraction that teaches',
#    'n\ta person whose occupation is teaching']},
#  {'word': 'lunch', 'score': 1283, 'tags': ['n'], 'defs': ['n\ta midday meal']},
#  {'word': 'students',
#   'score': 1273,
#   'tags': ['n'],
#   'defs': ['n\ta learner who is enrolled in an educational institution',
#    'n\ta learned person (especially in the humanities); someone who by long study has gained mastery in one or more disciplines'],
#   'defHeadword': 'student'}]

# %%
# "strongly rhyming words"
parameter = {"rel_rhy":"computer"}
request = requests.get('https://api.datamuse.com/words',parameter)
df = pd.json_normalize(request.json())
print(df.shape)
df.head()
# Out:
# (43, 3)
#       word  score  numSyllables
# 0    tutor    956             2
# 1   neuter    850             2
# 2   router    688             2
# 3   pewter    656             2
# 4  shooter    604             2

# %%
# only keep rows with an above average ryhming score
df_high = df[df.score > df.score.mean()]
df_high.shape
# Out:
# (14, 3)

# %%
df.score.mean()
# Out:
# 235.04651162790697

# %%
df_high
# Out:
#             word  score  numSyllables
# 0          tutor    956             2
# 1         neuter    850             2
# 2         router    688             2
# 3         pewter    656             2
# 4        shooter    604             2
# 5     prosecutor    580             4
# 6         suitor    564             2
# 7        scooter    546             2
# 8         hooter    519             2
# 9       commuter    460             3
# 10     recruiter    269             3
# 11  minicomputer    252             5
# 12         cuter    240             2
# 13  sharpshooter    239             3

# %% [markdown]
# # Excercise 2
#
# 1. Use the API snippet from The Guardian provided in the lecture, and the documentation available here https://open-platform.theguardian.com/documentation/, to create a custom query from the Guardian of your choosing. To complete this excercise, your custom query must return at least 20 rows of data. Use the API credential (key) provided in the function in the lecture notebook. If you receive an error regarding a conflciting query occuring at the same time, try to run the snippet again until you establish a succesful connection with the API/get a succesful response.
# 2. Conduct a basic exploratory analysis to explore what columns the dataset has, how many articles you retreived, and in what sections of the website they were published.
# 3. Play around with the webPublicationDate column which shows when the articles from your query were published. The column is NOT datetime and needs to be. Transform to datetime to visualise or otherwise informatively count the number of articles published on a particular date.

# %%
# original one from lecture notebook
def query_api(tag, from_date, page, api_key):
    """
    Function to query the API for a particular tag
    returns: a response from API
    """
    response = requests.get("https://content.guardianapis.com/search?tag="
                            + tag + "&from-date=" + from_date 
                            +"&page=" + str(page) + "&page-size=200&api-key=" + api_key)
    return response

# %%
# adapted to choose the content endpoint
def query_api2(query, from_date, page, api_key):
    """
    Function to query the API for a particular tag
    returns: a response from API
    """
    response = requests.get("https://content.guardianapis.com/search?q=" # note the change here
                            + query + "&from-date=" + from_date 
                            +"&page=" + str(page) + "&page-size=200&api-key=" + api_key)
    return response

# %%
response = query_api2('climate', '2022-01-01', '1', 'e723ffce-dfd5-427e-b9b8-779f5efedb02')
response # all went well
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 1314,
#   'startIndex': 1,
#   'pageSize': 200,
#   'currentPage': 1,
#   'pages': 7,
#   'orderBy': 'relevance',
#   'results': [{'id': 'news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#     'type': 'article',
#     'sectionId': 'news',
#     'sectionName': 'News',
#     'webPublicationDate': '2022-01-04T06:00:09Z',
#     'webTitle': 'Weatherwatch: Andorra’s continental and alpine climate',
#     'webUrl': 'https://www.theguardian.com/news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#     'apiUrl': 'https://content.guardianapis.com/news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#     'type': 'article',
#     'sectionId': 'news',
#     'sectionName': 'News',
#     'webPublicationDate': '2022-03-01T06:00:13Z',
#     'webTitle': 'Weatherwatch: the many climate zones of Chile',
#     'webUrl': 'https://www.theguardian.com/news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#     'apiUrl': 'https://content.guardianapis.com/news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/10/climate-change-fundamentally-affecting-european-birds-study-shows',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-10T10:22:43Z',
#     'webTitle': 'Climate change fundamentally affecting European birds, study shows ',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar

#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'uk-news/2022/mar/15/scotland-not-adapted-to-climate-crisis-says-advisory-committee',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-03-15T12:18:07Z',
#     'webTitle': 'Scotland not adapted to climate crisis, says advisory committee',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/mar/15/scotland-not-adapted-to-climate-crisis-says-advisory-committee',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/mar/15/scotland-not-adapted-to-climate-crisis-says-advisory-committee',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/10/oil-companies-corporate-free-speech-laws-climate-litigation',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-10T11:00:05Z',
#     'webTitle': 'How oil companies rebranded deceptive climate ads as ‘free speech’',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/10/oil-companies-corporate-free-speech-laws-climate-litigation',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/10/oil-companies-corporate-free-speech-laws-climate-litigation',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/07/climate-crisis-amazon-rainforest-tipping-point',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-07T16:00:46Z',
#     'webTitle': 'Climate crisis: Amazon rainforest tipping point is looming, data shows',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/07/climate-crisis-amazon-rainforest-tipping-point',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/07/climate-crisis-amazon-rainforest-tipping-point',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/07/us-beef-industry-cop26-methane-gas',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-07T11:05:35Z',
#     'webTitle': 'US beef industry emerges from Biden’s climate pledges ‘relatively unscathed’',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/07/us-beef-industry-cop26-methane-gas',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/07/us-beef-industry-cop26-methane-gas',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'world/2022/feb/09/germany-appoints-jennifer-morgan-ex-greenpeace-chief-climate-envoy',
#     'type': 'article',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2022-02-09T17:03:53Z',
#     'webTitle': 'Germany appoints ex-Greenpeace chief as special climate envoy',
#     'webUrl': 'https://www.theguardian.com/world/2022/feb/09/germany-appoints-jennifer-morgan-ex-greenpeace-chief-climate-envoy',
#     'apiUrl': 'https://content.guardianapis.com/world/2022/feb/09/germany-appoints-jennifer-morgan-ex-greenpeace-chief-climate-envoy',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/27/climate-emergency-a-national-security-concern-says-red-cross',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-27T18:17:29Z',
#     'webTitle': 'Climate emergency a ‘national security’ concern, says Red Cross',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/27/climate-emergency-a-national-security-concern-says-red-cross',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/27/climate-emergency-a-national-security-concern-says-red-cross',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'us-news/2022/feb/17/california-wildfires-increase-study',
#     'type': 'article',
#     'sectionId': 'us-news',
#     'sectionName': 'US news',
#     'webPublicationDate': '2022-02-17T10:00:32Z',
#     'webTitle': '‘Loading the dice’: climate crisis could increase southern California wildfires',
#     'webUrl': 'https://www.theguardian.com/us-news/2022/feb/17/california-wildfires-increase-study',
#     'apiUrl': 'https://content.guardianapis.com/us-news/2022/feb/17/california-wildfires-increase-study',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/16/constituents-set-up-steve-baker-watch-over-mps-climate-stance',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-16T16:15:25Z',
#     'webTitle': 'Constituents set up ‘Steve Baker Watch’ over MP’s climate stance',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/16/constituents-set-up-steve-baker-watch-over-mps-climate-stance',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/16/constituents-set-up-steve-baker-watch-over-mps-climate-stance',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'news/2022/feb/15/from-icy-mountains-to-subtropical-lowlands-bhutan-varied-climate',
#     'type': 'article',
#     'sectionId': 'news',
#     'sectionName': 'News',
#     'webPublicationDate': '2022-02-15T06:00:06Z',
#     'webTitle': 'From icy mountains to subtropical lowlands: Bhutan’s varied climate',
#     'webUrl': 'https://www.theguardian.com/news/2022/feb/15/from-icy-mountains-to-subtropical-lowlands-bhutan-varied-climate',
#     'apiUrl': 'https://content.guardianapis.com/news/2022/feb/15/from-icy-mountains-to-subtropical-lowlands-bhutan-varied-climate',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/14/just-stop-oil-activist-direct-action-against-uk-oil-infrastructure-target-petrol-stations-depots-refineries',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-14T15:30:34Z',
#     'webTitle': 'Climate activists plan direct action against UK oil infrastructure ',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/14/just-stop-oil-activist-direct-action-against-uk-oil-infrastructure-target-petrol-stations-depots-refineries',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/14/just-stop-oil-activist-direct-action-against-uk-oil-infrastructure-target-petrol-stations-depots-refineries',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'society/2022/jan/21/guardian-and-observer-climate-justice-charity-appeal',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2022-01-21T13:01:23Z',
#     'webTitle': 'Guardian and Observer climate justice charity appeal tops £1m',
#     'webUrl': 'https://www.theguardian.com/society/2022/jan/21/guardian-and-observer-climate-justice-charity-appeal',
#     'apiUrl': 'https://content.guardianapis.com/society/2022/jan/21/guardian-and-observer-climate-justice-charity-appeal',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/10/what-are-conservative-commentators-saying-about-the-floods-and-climate',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-09T22:53:21Z',
#     'webTitle': 'What are conservative commentators saying about the floods and climate? | Temperature Check',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/10/what-are-conservative-commentators-saying-about-the-floods-and-climate',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/10/what-are-conservative-commentators-saying-about-the-floods-and-climate',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'travel/2022/feb/12/ireland-nordic-inspired-wilderness-cabin-retreat-cabu-county-cavan',
#     'type': 'article',
#     'sectionId': 'travel',
#     'sectionName': 'Travel',
#     'webPublicationDate': '2022-02-12T11:00:06Z',
#     'webTitle': 'Loving a cold climate: Ireland’s Nordic-inspired wilderness retreat',
#     'webUrl': 'https://www.theguardian.com/travel/2022/feb/12/ireland-nordic-inspired-wilderness-cabin-retreat-cabu-county-cavan',
#     'apiUrl': 'https://content.guardianapis.com/travel/2022/feb/12/ireland-nordic-inspired-wilderness-cabin-retreat-cabu-county-cavan',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'science/2022/mar/02/terrawatch-how-carbon-eating-rocks-could-help-fight-climate-crisis',
#     'type': 'article',
#     'sectionId': 'science',
#     'sectionName': 'Science',
#     'webPublicationDate': '2022-03-02T06:00:32Z',
#     'webTitle': 'Terrawatch: how carbon-eating rocks could help fight climate crisis',
#     'webUrl': 'https://www.theguardian.com/science/2022/mar/02/terrawatch-how-carbon-eating-rocks-could-help-fight-climate-crisis',
#     'apiUrl': 'https://content.guardianapis.com/science/2022/mar/02/terrawatch-how-carbon-eating-rocks-could-help-fight-climate-crisis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/28/impact-of-climate-crisis-much-worse-than-predicted-says-alok-sharma',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-28T06:00:34Z',
#     'webTitle': 'Impact of climate crisis much worse than predicted, says Alok Sharma',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/28/impact-of-climate-crisis-much-worse-than-predicted-says-alok-sharma',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/28/impact-of-climate-crisis-much-worse-than-predicted-says-alok-sharma',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/28/ipcc-issues-bleakest-warning-yet-impacts-climate-breakdown',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-28T11:00:42Z',
#     'webTitle': 'IPCC issues ‘bleakest warning yet’ on impacts of climate breakdown',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/28/ipcc-issues-bleakest-warning-yet-impacts-climate-breakdown',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/28/ipcc-issues-bleakest-warning-yet-impacts-climate-breakdown',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/01/north-sea-abigail-oil-field-plan-approved-despite-climate-goals',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-02-01T18:20:22Z',
#     'webTitle': 'North Sea Abigail oilfield plan approved despite climate goals',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/01/north-sea-abigail-oil-field-plan-approved-despite-climate-goals',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/01/north-sea-abigail-oil-field-plan-approved-despite-climate-goals',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2022/jan/02/observer-view-britains-climate-crisis-targets',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2022-01-02T06:30:10Z',
#     'webTitle': 'The Observer view on Britain’s climate crisis targets | Observer editorial',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2022/jan/02/observer-view-britains-climate-crisis-targets',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2022/jan/02/observer-view-britains-climate-crisis-targets',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'tv-and-radio/2022/jan/24/alan-titchmarsh-avocados-climate-impact',
#     'type': 'article',
#     'sectionId': 'tv-and-radio',
#     'sectionName': 'Television & radio',
#     'webPublicationDate': '2022-01-24T12:09:11Z',
#     'webTitle': 'Alan Titchmarsh says he avoids avocados because of climate impact',
#     'webUrl': 'https://www.theguardian.com/tv-and-radio/2022/jan/24/alan-titchmarsh-avocados-climate-impact',
#     'apiUrl': 'https://content.guardianapis.com/tv-and-radio/2022/jan/24/alan-titchmarsh-avocados-climate-impact',
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'},
#    {'id': 'artanddesign/2022/mar/12/sydney-biennale-2022-amid-floods-arrives-art-with-an-urgent-climate-message',
#     'type': 'article',
#     'sectionId': 'artanddesign',
#     'sectionName': 'Art and design',
#     'webPublicationDate': '2022-03-11T19:00:38Z',
#     'webTitle': 'Sydney biennale 2022: amid floods arrives art with an urgent climate message',
#     'webUrl': 'https://www.theguardian.com/artanddesign/2022/mar/12/sydney-biennale-2022-amid-floods-arrives-art-with-an-urgent-climate-message',
#     'apiUrl': 'https://content.guardianapis.com/artanddesign/2022/mar/12/sydney-biennale-2022-amid-floods-arrives-art-with-an-urgent-climate-message',
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'},
#    {'id': 'australia-news/2022/mar/09/farmers-report-warns-climate-crisis-puts-australias-food-supply-at-increasing-risk',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-03-08T17:00:09Z',
#     'webTitle': 'Farmers’ report warns climate crisis puts Australia’s food supply at increasing risk',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/mar/09/farmers-report-warns-climate-crisis-puts-australias-food-supply-at-increasing-risk',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/mar/09/farmers-report-warns-climate-crisis-puts-australias-food-supply-at-increasing-risk',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/07/dont-let-high-energy-prices-derail-uk-green-agenda-say-climate-experts',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-07T19:18:17Z',
#     'webTitle': 'Don’t let high energy prices derail UK green agenda, say climate experts',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/07/dont-let-high-energy-prices-derail-uk-green-agenda-say-climate-experts',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/07/dont-let-high-energy-prices-derail-uk-green-agenda-say-climate-experts',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/14/mexico-cancun-beaches-tourism-sea-levels-climate-crisis-quintana-roo',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03

#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/jan/09/tv-explorer-simon-reeve-fears-documentaries-make-him-a-climate-hypocrite',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-01-09T00:15:05Z',
#     'webTitle': 'TV explorer Simon Reeve fears documentaries make him a climate ‘hypocrite’',
#     'webUrl': 'https://www.theguardian.com/environment/2022/jan/09/tv-explorer-simon-reeve-fears-documentaries-make-him-a-climate-hypocrite',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/jan/09/tv-explorer-simon-reeve-fears-documentaries-make-him-a-climate-hypocrite',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/02/flowers-arriving-month-early-uk-climate-heats-up-bloom-insects-birds',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-02T06:00:16Z',
#     'webTitle': 'Flowers arriving a month early in UK as climate heats up',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/02/flowers-arriving-month-early-uk-climate-heats-up-bloom-insects-birds',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/02/flowers-arriving-month-early-uk-climate-heats-up-bloom-insects-birds',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'film/2022/jan/08/dont-look-up-four-climate-experts-on-the-polarising-disaster-film',
#     'type': 'article',
#     'sectionId': 'film',
#     'sectionName': 'Film',
#     'webPublicationDate': '2022-01-08T08:00:46Z',
#     'webTitle': 'Don’t Look Up: four climate experts on the polarising disaster film',
#     'webUrl': 'https://www.theguardian.com/film/2022/jan/08/dont-look-up-four-climate-experts-on-the-polarising-disaster-film',
#     'apiUrl': 'https://content.guardianapis.com/film/2022/jan/08/dont-look-up-four-climate-experts-on-the-polarising-disaster-film',
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'},
#    {'id': 'environment/2022/jan/11/boris-johnson-climate-action-net-zero-conservative-party',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-01-11T18:08:04Z',
#     'webTitle': 'Johnson’s political weakness leaves climate agenda at risk, say campaigners',
#     'webUrl': 'https://www.theguardian.com/environment/2022/jan/11/boris-johnson-climate-action-net-zero-conservative-party',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/jan/11/boris-johnson-climate-action-net-zero-conservative-party',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'artanddesign/2022/jan/27/noemie-goudal-post-atlantica',
#     'type': 'article',
#     'sectionId': 'artanddesign',
#     'sectionName': 'Art and design',
#     'webPublicationDate': '2022-01-27T12:16:18Z',
#     'webTitle': '‘We have to be more humble’: the artist predicting our climate future',
#     'webUrl': 'https://www.theguardian.com/artanddesign/2022/jan/27/noemie-goudal-post-atlantica',
#     'apiUrl': 'https://content.guardianapis.com/artanddesign/2022/jan/27/noemie-goudal-post-atlantica',
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'},
#    {'id': 'environment/2022/jan/27/word-salad-of-nonsense-scientists-denounce-jordan-petersons-comments-on-climate-models',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-01-27T07:05:45Z',
#     'webTitle': '‘Word salad of nonsense’: scientists denounce Jordan Peterson’s comments on climate models',
#     'webUrl': 'https://www.theguardian.com/environment/2022/jan/27/word-salad-of-nonsense-scientists-denounce-jordan-petersons-comments-on-climate-models',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/jan/27/word-salad-of-nonsense-scientists-denounce-jordan-petersons-comments-on-climate-models',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/15/manchin-reluctant-electric-cars-biden-climate-crisis-fight',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-15T06:00:43Z',
#     'webTitle': 'Manchin ‘very reluctant’ on electric cars in ominous sign for Biden’s climate fight',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/15/manchin-reluctant-electric-cars-biden-climate-crisis-fight',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar

#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/17/the-stealth-operative-for-big-oil-whos-out-to-derail-americas-climate-fight',
# ...
#     'pillarName': 'News'},
#    {'id': 'uk-news/2022/jan/18/northern-ireland-environment-plan-weak-flawed-dirty-corner-europe',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-01-18T13:05:15Z',
#     'webTitle': 'Northern Ireland could become ‘dirty corner of Europe’, say campaigners',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/jan/18/northern-ireland-environment-plan-weak-flawed-dirty-corner-europe',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/jan/18/northern-ireland-environment-plan-weak-flawed-dirty-corner-europe',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'world/2022/jan/06/urban-fire-storm-suburban-sprawl-wildfires-colorado',
#     'type': 'article',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2022-01-06T11:00:00Z',
#     'webTitle': '‘Urban fire storm’: suburban sprawl raising risk of destructive wildfires',
#     'webUrl': 'https://www.theguardian.com/world/2022/jan/06/urban-fire-storm-suburban-sprawl-wildfires-colorado',
#     'apiUrl': 'https://content.guardianapis.com/world/2022/jan/06/urban-fire-storm-suburban-sprawl-wildfires-colorado',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/jan/28/five-great-reads-jordan-peterson-fact-checked-covid-denialists-utopia-and-pandemic-sex',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-01-27T23:54:52Z',
#     'webTitle': 'Five Great Reads: Jordan Peterson fact-checked, Covid denialists’ utopia and pandemic sex',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/jan/28/five-great-reads-jordan-peterson-fact-checked-covid-denialists-utopia-and-pandemic-sex',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/jan/28/five-great-reads-jordan-peterson-fact-checked-covid-denialists-utopia-and-pandemic-sex',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'sport/2022/mar/02/womens-world-cup-2022-prepares-to-start-after-a-bodged-buildup-by-icc',
#     'type': 'article',
#     'sectionId': 'sport',
#     'sectionName': 'Sport',
#     'webPublicationDate': '2022-03-02T10:14:13Z',
#     'webTitle': 'The Spin | Women’s Cricket World Cup prepares to start after a bodged buildup',
#     'webUrl': 'https://www.theguardian.com/sport/2022/mar/02/womens-world-cup-2022-prepares-to-start-after-a-bodged-buildup-by-icc',
#     'apiUrl': 'https://content.guardianapis.com/sport/2022/mar/02/womens-world-cup-2022-prepares-to-start-after-a-bodged-buildup-by-icc',
#     'isHosted': False,
#     'pillarId': 'pillar/sport',
#     'pillarName': 'Sport'},
#    {'id': 'world/2022/jan/04/beavers-arctic-north-climate-crisis',
#     'type': 'article',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2022-01-04T11:00:10Z',
#     'webTitle': 'Dam it: beavers head north to the Arctic as tundra continues to heat up',
#     'webUrl': 'https://www.theguardian.com/world/2022/jan/04/beavers-arctic-north-climate-crisis',
#     'apiUrl': 'https://content.guardianapis.com/world/2022/jan/04/beavers-arctic-north-climate-crisis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/15/us-west-megadrought-worst-1200-years-study',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-15T12:27:49Z',
#     'webTitle': 'US west ‘megadrought’ is worst in at least 1,200 years, new study says',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/15/us-west-megadrought-worst-1200-years-study',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/15/us-west-megadrought-worst-1200-years-study',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'science/2022/mar/09/joe-biden-fossil-name-vampire-squid',
#     'type': 'article',
#     'sectionId': 'science',
#     'sectionName': 'Science',
#     'webPublicationDate': '2022-03-09T16:42:36Z',
#     'webTitle': 'Joe Biden is a fossil: 328m-year-old vampire squid named after president',
#     'webUrl': 'https://www.theguardian.com/science/2022/mar/09/joe-biden-fossil-name-vampire-squid',
#     'apiUrl': 'https://content.guardianapis.com/science/2022/mar/09/joe-biden-fossil-name-vampire-squid',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'us-news/2022/feb/24/first-thing-putin-declares-war-russia-invades-ukraine',
#     'type': 'article',
#     'sectionId': 'us-news',
#     'sectionName': 'US news',
#     'webPublicationDate': '2022-02-24T12:53:39Z',
#     'webTitle': 'First Thing: Putin unleashes Russian invasion of Ukraine',
#     'webUrl': 'https://www.theguardian.com/us-news/2022/feb/24/first-thing-putin-declares-war-russia-invades-ukraine',
#     'apiUrl': 'https://content.guardianapis.com/us-news/2022/feb/24/first-thing-putin-declares-war-russia-invades-ukraine',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/05/dishonest-morrison-government-wanted-ipcc-to-say-great-barrier-reef-not-yet-in-crisis',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-04T22:53:54Z',
#     'webTitle': '‘Unscientific’: Morrison government wanted IPCC to say Great Barrier Reef ‘not yet in crisis’',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/05/dishonest-morrison-government-wanted-ipcc-to-say-great-barrier-reef-not-yet-in-crisis',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/05/dishonest-morrison-government-wanted-ipcc-to-say-great-barrier-reef-not-yet-in-crisis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/06/amazon-ikea-nestle-biggest-carbon-net-zero-claims',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-06T23:01:37Z',
#     'webTitle': 'World’s biggest firms failing over net-zero claims, research suggests',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/06/amazon-ikea-nestle-biggest-carbon-net-zero-claims',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/06/amazon-ikea-nestle-biggest-carbon-net-zero-claims',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/jan/23/uks-biggest-private-pension-fund-to-shift-5bn-away-from-polluters',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-01-23T16:23:54Z',
#     'webTitle': 'UK’s biggest private pension fund to shift £5bn away from polluters',
#     'webUrl': 'https://www.theguardian.com/business/2022/jan/23/uks-biggest-private-pension-fund-to-shift-5bn-away-from-polluters',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/jan/23/uks-biggest-private-pension-fund-to-shift-5bn-away-from-polluters',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/mar/06/worse-than-2017-lismore-faces-mammoth-rebuild-after-flood-as-community-inundated-by-loss',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-03-05T19:00:32Z',
#     'webTitle': '‘Worse than 2017’: Lismore faces mammoth rebuild after flood as community inundated by loss',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/mar/06/worse-than-2017-lismore-faces-mammoth-rebuild-after-flood-as-community-inundated-by-loss',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/mar/06/worse-than-2017-lismore-faces-mammoth-rebuild-after-flood-as-community-inundated-by-loss',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/mar/01/insect-crisis-book-climate-bees-moths-roaches-flies-facts',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-03-01T10:00:11Z',
#     'webTitle': 'Bees can play soccer – 10 little-known facts about insects',
#     'webUrl': 'https://www.theguardian.com/environment/2022/mar/01/insect-crisis-book-climate-bees-moths-roaches-flies-facts',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/01/insect-crisis-book-climate-bees-moths-roaches-flies-facts',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/mar/11/ive-alway-been-on-the-blue-spectrum-dave-sharma-denies-mimicking-independent-rivals-colour-scheme',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-03-11T04:28:58Z',
#     'webTitle': '‘I’ve always been on the blue spectrum’: Dave Sharma denies mimicking independent rival’s colour scheme',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/mar/11/ive-alway-been-on-the-blue-spectrum-dave-sharma-denies-mimicking-independent-rivals-colour-scheme',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/mar/11/ive-alway-been-on-the-blue-spectrum-dave-sharma-denies-mimicking-independent-rivals-colour-scheme',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/feb/17/land-clearing-in-nsw-triples-over-past-decade-state-of-the-environment-2021-report-reveals',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-16T16:30:11Z',
#     'webTitle': 'Land clearing in NSW tripled over past decade, State of the Environment 2021 report reveals',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/feb/17/land-clearing-in-nsw-triples-over-past-decade-state-of-the-environment-2021-report-reveals',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/feb/17/land-clearing-in-nsw-triples-over-past-decade-state-of-the-environment-2021-report-reveals',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/feb/02/flooding-cuts-off-railway-supply-routes-to-northern-australia',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-02-01T16:30:01Z',
#     'webTitle': 'Flooding cuts off key railway supply routes in central Australia',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/feb/02/flooding-cuts-off-railway-supply-routes-to-northern-australia',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/feb/02/flooding-cuts-off-railway-supply-routes-to-northern-australia',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'uk-news/2022/jan/18/sadiq-khan-proposes-journey-charge-for-motorists-in-london',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-01-18T00:01:40Z',
#     'webTitle': 'Sadiq Khan proposes journey charge for motorists in London',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/jan/18/sadiq-khan-proposes-journey-charge-for-motorists-in-london',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/jan/18/sadiq-khan-proposes-journey-charge-for-motorists-in-london',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/mar/13/the-lnp-are-feeling-threatened-the-growing-ambition-of-independents-challenging-coalition-mps',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-03-12T19:00:08Z',
#     'webTitle': '‘The LNP are feeling threatened’: the growing ambition of independents challenging Coalition MPs',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/mar/13/the-lnp-are-feeling-threatened-the-growing-ambition-of-independents-challenging-coalition-mps',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/mar/13/the-lnp-are-feeling-threatened-the-growing-ambition-of-independents-challenging-coalition-mps',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2022/mar/13/nigel-farage-hard-right-faction-brexit-net-zero-tory',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2022-03-13T12:53:54Z',
#     'webTitle': 'Nigel Farage’s hard-right faction won Brexit. Now net zero is in its sights | John Harris',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2022/mar/13/nigel-farage-hard-right-faction-brexit-net-zero-tory',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2022/mar/13/nigel-farage-hard-right-faction-brexit-net-zero-tory',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'environment/2022/feb/22/were-quite-fed-up-britons-on-weathering-the-aftermath-of-three-storms',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-22T06:00:04Z',
#     'webTitle': '‘We’re quite fed up’: Britons on weathering the aftermath of three storms',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/22/were-quite-fed-up-britons-on-weathering-the-aftermath-of-three-storms',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/22/were-quite-fed-up-britons-on-weathering-the-aftermath-of-three-storms',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2022/mar/15/its-bigger-than-just-new-england-mayor-during-black-summer-bushfires-to-run-against-barnaby-joyce',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2022-03-14T16:30:27Z',
#     'webTitle': '‘It’s bigger than just New England’: mayor during black summer bushfires to run against Barnaby Joyce',
#     'webUrl': 'https://www.theguardian.com/australia-news/2022/mar/15/its-bigger-than-just-new-england-mayor-during-black-summer-bushfires-to-run-against-barnaby-joyce',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2022/mar/15/its-bigger-than-just-new-england-mayor-during-black-summer-bushfires-to-run-against-barnaby-joyce',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2022/feb/11/uk-net-zero-goal-is-backed-by-nearly-all-mps',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2022-02-11T06:00:41Z',
#     'webTitle': 'The UK’s net zero goal is backed by nearly all MPs | Letters',
#     'webUrl': 'https://www.theguardian.com/environment/2022/feb/11/uk-net-zero-goal-is-backed-by-nearly-all-mps',
#     'apiUrl': 'https://content.guardianapis.com/environment/2022/feb/11/uk-net-zero-goal-is-backed-by-nearly-all-mps',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'lifeandstyle/2022/jan/23/james-wong-on-gardens-some-supposedly-exotic-plants-love-life-here-in-the-uk',
#     'type': 'article',
#     'sectionId': 'lifeandstyle',
#     'sectionName': 'Life and style',
#     'webPublicationDate': '2022-01-23T08:15:16Z',
#     'webTitle': 'The exotic plants that love life in the UK',
#     'webUrl': 'https://www.theguardian.com/lifeandstyle/2022/jan/23/james-wong-on-gardens-some-supposedly-exotic-plants-love-life-here-in-the-uk',
#     'apiUrl': 'https://content.guardianapis.com/lifeandstyle/2022/jan/23/james-wong-on-gardens-some-supposedly-exotic-plants-love-life-here-in-the-uk',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'}]}}

# %% [markdown]
# This is the same: https://content.guardianapis.com/search?q=climate&from-date=2022-01-01&page=1&page-size=200&api-key=e723ffce-dfd5-427e-b9b8-779f5efedb02

# %%
df = pd.json_normalize(response.json()['response']['results'])
df.head()
# Out:
#                                                   id     type    sectionId  \
# 0  news/2022/jan/04/weatherwatch-andorra-continen...  article         news
# 1  news/2022/mar/01/weatherwatch-many-climate-zon...  article         news
# 2  environment/2022/mar/10/climate-change-fundame...  article  environment
# 3  us-news/2022/feb/12/trump-judge-biden-climate-...  article      us-news
# 4  environment/2022/feb/10/climate-activists-buy-...  article  environment
#
#    sectionName    webPublicationDate  \
# 0         News  2022-01-04T06:00:09Z
# 1         News  2022-03-01T06:00:13Z
# 2  Environment  2022-03-10T10:22:43Z
# 3      US news  2022-02-12T14:54:44Z
# 4  Environment  2022-02-10T13:26:46Z
#
#                                             webTitle  \
# 0  Weatherwatch: Andorra’s continental and alpine...
# 1      Weatherwatch: the many climate zones of Chile
# 2  Climate change fundamentally affecting Europea...
# 3   Trump-appointed judge blocks Biden administra...
# 4  Climate activists buy environment secretary’s ...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/news/2022/jan/04/w...
# 1  https://www.theguardian.com/news/2022/mar/01/w...
# 2  https://www.theguardian.com/environment/2022/m...
# 3  https://www.theguardian.com/us-news/2022/feb/1...
# 4  https://www.theguardian.com/environment/2022/f...
#
#                                               apiUrl  isHosted     pillarId  \
# 0  https://content.guardianapis.com/news/2022/jan...     False  pillar/news
# 1  https://content.guardianapis.com/news/2022/mar...     False  pillar/news
# 2  https://content.guardianapis.com/environment/2...     False  pillar/news
# 3  https://content.guardianapis.com/us-news/2022/...     False  pillar/news
# 4  https://content.guardianapis.com/environment/2...     False  pillar/news
#
#   pillarName
# 0       News
# 1       News
# 2       News
# 3       News
# 4       News

# %%
# what columns are returned?
df.columns
# Out:
# Index(['id', 'type', 'sectionId', 'sectionName', 'webPublicationDate',
#        'webTitle', 'webUrl', 'apiUrl', 'isHosted', 'pillarId', 'pillarName'],
#       dtype='object')

# %%
# how many articles/rows are there?
len(df)
# Out:
# 200

# %%
# in which sections of the Guardian are they published?
df['sectionId'].value_counts()
# Out:
# environment                   84
# commentisfree                 22
# australia-news                18
# us-news                        8
# world                          8
# global-development             7
# uk-news                        6
# society                        6
# business                       6
# news                           5
# lifeandstyle                   4
# science                        4
# politics                       4
# books                          3
# film                           2
# culture                        2
# artanddesign                   2
# education                      2
# travel                         2
# tv-and-radio                   1
# reimagining-sustainability     1
# law                            1
# fashion                        1
# sport                          1
# Name: sectionId, dtype: int64

# %%
# data types of my columns
df.dtypes
# Out:
# id                    object
# type                  object
# sectionId             object
# sectionName           object
# webPublicationDate    object
# webTitle              object
# webUrl                object
# apiUrl                object
# isHosted                bool
# pillarId              object
# pillarName            object
# dtype: object

# %%
df.head()
# Out:
#                                                   id     type    sectionId  \
# 0  news/2022/jan/04/weatherwatch-andorra-continen...  article         news
# 1  news/2022/mar/01/weatherwatch-many-climate-zon...  article         news
# 2  environment/2022/mar/10/climate-change-fundame...  article  environment
# 3  us-news/2022/feb/12/trump-judge-biden-climate-...  article      us-news
# 4  environment/2022/feb/10/climate-activists-buy-...  article  environment
#
#    sectionName    webPublicationDate  \
# 0         News  2022-01-04T06:00:09Z
# 1         News  2022-03-01T06:00:13Z
# 2  Environment  2022-03-10T10:22:43Z
# 3      US news  2022-02-12T14:54:44Z
# 4  Environment  2022-02-10T13:26:46Z
#
#                                             webTitle  \
# 0  Weatherwatch: Andorra’s continental and alpine...
# 1      Weatherwatch: the many climate zones of Chile
# 2  Climate change fundamentally affecting Europea...
# 3   Trump-appointed judge blocks Biden administra...
# 4  Climate activists buy environment secretary’s ...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/news/2022/jan/04/w...
# 1  https://www.theguardian.com/news/2022/mar/01/w...
# 2  https://www.theguardian.com/environment/2022/m...
# 3  https://www.theguardian.com/us-news/2022/feb/1...
# 4  https://www.theguardian.com/environment/2022/f...
#
#                                               apiUrl  isHosted     pillarId  \
# 0  https://content.guardianapis.com/news/2022/jan...     False  pillar/news
# 1  https://content.guardianapis.com/news/2022/mar...     False  pillar/news
# 2  https://content.guardianapis.com/environment/2...     False  pillar/news
# 3  https://content.guardianapis.com/us-news/2022/...     False  pillar/news
# 4  https://content.guardianapis.com/environment/2...     False  pillar/news
#
#   pillarName
# 0       News
# 1       News
# 2       News
# 3       News
# 4       News

# %%
# make new column in datetime format
df['date'] = pd.to_datetime(df['webPublicationDate'])
df.dtypes
# Out:
# id                                 object
# type                               object
# sectionId                          object
# sectionName                        object
# webPublicationDate                 object
# webTitle                           object
# webUrl                             object
# apiUrl                             object
# isHosted                             bool
# pillarId                           object
# pillarName                         object
# date                  datetime64[ns, UTC]
# dtype: object

# %%
# how many per day
df.groupby(df['date'].dt.date).size()
# Out:
# date
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    1
# 2022-01-04    2
# 2022-01-06    2
#              ..
# 2022-03-12    4
# 2022-03-13    4
# 2022-03-14    4
# 2022-03-15    6
# 2022-03-16    2
# Length: 63, dtype: int64

# %%
# visualize over time per day
df.groupby(df['date'].dt.date).size().plot()
# select only the date (not time) from the datetime column, calculate how many (size) and plot
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Alternative (worse!) approach: remove time from the string
df['date_str'] = df['webPublicationDate'].str[0:10] # we know that the first 10 characters is the date.
df[['webPublicationDate', 'date_str']].head()
# Out:
#      webPublicationDate    date_str
# 0  2022-01-04T06:00:09Z  2022-01-04
# 1  2022-03-01T06:00:13Z  2022-03-01
# 2  2022-03-10T10:22:43Z  2022-03-10
# 3  2022-02-12T14:54:44Z  2022-02-12
# 4  2022-02-10T13:26:46Z  2022-02-10

# %%
df.groupby(df['date_str']).size()
# Out:
# date_str
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    1
# 2022-01-04    2
# 2022-01-06    2
#              ..
# 2022-03-12    4
# 2022-03-13    4
# 2022-03-14    4
# 2022-03-15    6
# 2022-03-16    2
# Length: 63, dtype: int64

# %% [markdown]
# ### EXTRA: What if I want the first 5 pages? Let's create a for loop

# %%
resp = []
for p in range(1,6):
    print(p)
    response = query_api2('climate', '2022-01-01', p, 'e723ffce-dfd5-427e-b9b8-779f5efedb02')
    resp.extend(response.json()['response']['results']) # extending(!) the list (= one big list) instead of appending (= list of lists)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# now we have way more
len(resp)
# Out:
# 1000

# %%
# this is how the first 3 look like
resp[0:3]
# Out:
# [{'id': 'news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#   'type': 'article',
#   'sectionId': 'news',
#   'sectionName': 'News',
#   'webPublicationDate': '2022-01-04T06:00:09Z',
#   'webTitle': 'Weatherwatch: Andorra’s continental and alpine climate',
#   'webUrl': 'https://www.theguardian.com/news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#   'apiUrl': 'https://content.guardianapis.com/news/2022/jan/04/weatherwatch-andorra-continental-alpine-climate',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#   'type': 'article',
#   'sectionId': 'news',
#   'sectionName': 'News',
#   'webPublicationDate': '2022-03-01T06:00:13Z',
#   'webTitle': 'Weatherwatch: the many climate zones of Chile',
#   'webUrl': 'https://www.theguardian.com/news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#   'apiUrl': 'https://content.guardianapis.com/news/2022/mar/01/weatherwatch-many-climate-zones-chile',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'environment/2022/mar/10/climate-change-fundamentally-affecting-european-birds-study-shows',
#   'type': 'article',
#   'sectionId': 'environment',
#   'sectionName': 'Environment',
#   'webPublicationDate': '2022-03-10T10:22:43Z',
#   'webTitle': 'Climate change fundamentally affecting European birds, study shows ',
#   'webUrl': 'https://www.theguardian.com/environment/2022/mar/10/climate-change-fundamentally-affecting-european-birds-study-shows',
#   'apiUrl': 'https://content.guardianapis.com/environment/2022/mar/10/climate-change-fundamentally-affecting-european-birds-study-shows',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'}]

# %%
# convert to dataframe
df_more = pd.json_normalize(resp)
len(df_more)
# Out:
# 1000

# %%
df_more.head()
# Out:
#                                                   id     type    sectionId  \
# 0  news/2022/jan/04/weatherwatch-andorra-continen...  article         news
# 1  news/2022/mar/01/weatherwatch-many-climate-zon...  article         news
# 2  environment/2022/mar/10/climate-change-fundame...  article  environment
# 3  us-news/2022/feb/12/trump-judge-biden-climate-...  article      us-news
# 4  environment/2022/feb/10/climate-activists-buy-...  article  environment
#
#    sectionName    webPublicationDate  \
# 0         News  2022-01-04T06:00:09Z
# 1         News  2022-03-01T06:00:13Z
# 2  Environment  2022-03-10T10:22:43Z
# 3      US news  2022-02-12T14:54:44Z
# 4  Environment  2022-02-10T13:26:46Z
#
#                                             webTitle  \
# 0  Weatherwatch: Andorra’s continental and alpine...
# 1      Weatherwatch: the many climate zones of Chile
# 2  Climate change fundamentally affecting Europea...
# 3   Trump-appointed judge blocks Biden administra...
# 4  Climate activists buy environment secretary’s ...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/news/2022/jan/04/w...
# 1  https://www.theguardian.com/news/2022/mar/01/w...
# 2  https://www.theguardian.com/environment/2022/m...
# 3  https://www.theguardian.com/us-news/2022/feb/1...
# 4  https://www.theguardian.com/environment/2022/f...
#
#                                               apiUrl  isHosted     pillarId  \
# 0  https://content.guardianapis.com/news/2022/jan...     False  pillar/news
# 1  https://content.guardianapis.com/news/2022/mar...     False  pillar/news
# 2  https://content.guardianapis.com/environment/2...     False  pillar/news
# 3  https://content.guardianapis.com/us-news/2022/...     False  pillar/news
# 4  https://content.guardianapis.com/environment/2...     False  pillar/news
#
#   pillarName
# 0       News
# 1       News
# 2       News
# 3       News
# 4       News
