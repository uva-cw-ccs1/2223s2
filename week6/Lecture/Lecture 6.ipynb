# %% [markdown]
# # Collecting and analyzing data beyond numbers
#
# Welcome to the sixth week of the course. By the end of this week, you should acquire:
#
# **Knowledge on:**
# * What an Application Programming Interface is
# * The various ways in which APIs can be used
# * The concept of authentication and it's pains
# * Basic HTTP responses
#
# **Skills on:**
# * Interacting with a basic API
# * Working with different types of data
#
# In today's class we will rely on some pretty basic Python packages such as *requests*.

# %%
import time # allows us to do interesting things with time objects and the passage of time
import json #allows us to interact with json objects (which is what a lot of APIs communciate in)
import requests #allows us to make so-called http requests, i.e. the same thing you do whenever you launch facebook in a broswer
import pandas as pd

# %% [markdown]
# # Basic APIs - cat facts!

# %%
data = requests.get('https://catfact.ninja/fact')

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'fact': 'Cats have "nine lives" thanks to a flexible spine and powerful leg and back muscles',
#  'length': 83}

# %%
#To get multiple facts, we can use our Python knowledge from previous weeks 
counter=0
cats=[]
while counter<30:
    data = requests.get('https://catfact.ninja/fact')
    cats.append(data.json())
    counter+=1

# %%
#What did we get?
cats_df = pd.DataFrame.from_dict(cats)

# %%
cats
# Out:
# [{'fact': 'A female cat will be pregnant for approximately 9 weeks or between 62 and 65 days from conception to delivery.',
#   'length': 110},
#  {'fact': 'Many cats love having their forehead gently stroked.',
#   'length': 52},
#  {'fact': 'People who are allergic to cats are actually allergic to cat saliva or to cat dander. If the resident cat is bathed regularly the allergic people tolerate it better.',
#   'length': 165},
#  {'fact': 'Cats only use their meows to talk to humans, not each other. The only time they meow to communicate with other felines is when they are kittens to signal to their mother.',
#   'length': 170},
#  {'fact': 'When a cat chases its prey, it keeps its head level. Dogs and humans bob their heads up and down.',
#   'length': 97},
#  {'fact': 'The smallest pedigreed cat is a Singapura, which can weigh just 4 lbs (1.8 kg), or about five large cans of cat food. The largest pedigreed cats are Maine Coon cats, which can weigh 25 lbs (11.3 kg), or nearly twice as much as an average cat weighs.',
#   'length': 249},
#  {'fact': 'Cats have "nine lives" thanks to a flexible spine and powerful leg and back muscles',
#   'length': 83},
#  {'fact': 'In relation to their body size, cats have the largest eyes of any mammal.',
#   'length': 73},
#  {'fact': 'Unlike humans, cats are usually lefties. Studies indicate that their left paw is typically their dominant paw.',
#   'length': 110},
#  {'fact': 'Perhaps the most famous comic cat is the Cheshire Cat in Lewis Carroll’s Alice in Wonderland. With the ability to disappear, this mysterious character embodies the magic and sorcery historically associated with cats.',
#   'length': 216},
#  {'fact': "A cat's field of vision is about 200 degrees.", 'length': 45},
#  {'fact': 'Some notable people who disliked cats:  Napoleon Bonaparte, Dwight D. Eisenhower, Hitler.',
#   'length': 89},
#  {'fact': 'Cats have 32 muscles that control the outer ear (humans have only 6). A cat can independently rotate its ears 180 degrees.',
#   'length': 122},
#  {'fact': 'If a cat is frightened, the hair stands up fairly evenly all over the body; when the cat is threatened or is ready to attack, the hair stands up only in a narrow band along the spine and tail.',
#   'length': 192},
#  {'fact': 'Some cats have survived falls of over 65 feet (20 meters), due largely to their “righting reflex.” The eyes and balance organs in the inner ear tell it where it is in space so the cat can land on its feet. Even cats without a tail have this ability.',
#   'length': 249},
#  {'fact': 'Statistics indicate that animal lovers in recent years have shown a preference for cats over dogs!',
#   'length': 98},
#  {'fact': "Cats have 32 muscles that control the outer ear (compared to human's 6 muscles each). A cat can rotate its ears independently 180 degrees, and can turn in the direction of sound 10 times faster than those of the best watchdog.",
#   'length': 226},
#  {'fact': 'It has been scientifically proven that owning cats is good for our health and can decrease the occurrence of high blood pressure and other illnesses.',
#   'length': 149},
#  {'fact': 'The first official cat show in the UK was organised at Crystal Palace in 1871.',
#   'length': 78},
#  {'fact': 'There are approximately 100 breeds of cat.', 'length': 42},
#  {'fact': "Cats respond better to women than to men, probably due to the fact that women's voices have a higher pitch.",
#   'length': 107},
#  {'fact': "The chlorine in fresh tap water irritates sensitive parts of the cat's nose. Let tap water sit for 24 hours before giving it to a cat.",
#   'length': 134},
#  {'fact': "The domestic cat is the only species able to hold its tail vertically while walking. You can also learn about your cat's present state of mind by observing the posture of his tail.",
#   'length': 180},
#  {'fact': 'Cats have individual preferences for scratching surfaces and angles. Some are horizontal scratchers while others exercise their claws vertically.',
#   'length': 145},
#  {'fact': 'Ailurophile is the word cat lovers are officially called.',
#   'length': 57},
#  {'fact': 'The leopard is the most widespread of all big cats.', 'length': 51},
#  {'fact': 'Unlike dogs, cats do not have a sweet tooth. Scientists believe this is due to a mutation in a key taste receptor.',
#   'length': 114},
#  {'fact': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#   'length': 68},
#  {'fact': 'The largest cat breed is the Ragdoll. Male Ragdolls weigh between 12 and 20 lbs (5.4-9.0 k). Females weigh between 10 and 15 lbs (4.5-6.8 k).',
#   'length': 141},
#  {'fact': 'In Japan, cats are thought to have the power to turn into super spirits when they die. This may be because according to the Buddhist religion, the body of the cat is the temporary resting place of very spiritual people.i',
#   'length': 220}]

# %% [markdown]
# # Basic APIs - rhyming words!

# %%
#Check out the docs here https://www.datamuse.com/api/
parameter = {"rel_rhy":"bye"}
request = requests.get('https://api.datamuse.com/words',parameter)

# %%
print(request.json())
# Out:
# [{'word': 'lie', 'score': 8446, 'numSyllables': 1}, {'word': 'i', 'score': 5939, 'numSyllables': 1}, {'word': 'by', 'score': 5817, 'numSyllables': 1}, {'word': 'fly', 'score': 5385, 'numSyllables': 1}, {'word': 'eye', 'score': 5205, 'numSyllables': 1}, {'word': 'hi', 'score': 3146, 'numSyllables': 1}, {'word': 'pie', 'score': 3095, 'numSyllables': 1}, {'word': 'buy', 'score': 2960, 'numSyllables': 1}, {'word': 'high', 'score': 2530, 'numSyllables': 1}, {'word': 'tie', 'score': 2494, 'numSyllables': 1}, {'word': 'apply', 'score': 2396, 'numSyllables': 2}, {'word': 'die', 'score': 2334, 'numSyllables': 1}, {'word': 'ally', 'score': 2287, 'numSyllables': 2}, {'word': 'supply', 'score': 2216, 'numSyllables': 2}, {'word': 'identify', 'score': 2126, 'numSyllables': 4}, {'word': 'dry', 'score': 2094, 'numSyllables': 1}, {'word': 'sky', 'score': 1876, 'numSyllables': 1}, {'word': 'shy', 'score': 1866, 'numSyllables': 1}, {'word': 'wry', 'score': 1789, 'numSyllables': 1}, {'word': 'alumni', 'score': 1760, 'numSyllables': 3}, {'word': 'comply', 'score': 1758, 'numSyllables': 2}, {'word': 'belie', 'score': 1755, 'numSyllables': 2}, {'word': 'imply', 'score': 1718, 'numSyllables': 2}, {'word': 'awry', 'score': 1704, 'numSyllables': 2}, {'word': 'cry', 'score': 1696, 'numSyllables': 1}, {'word': 'reply', 'score': 1685, 'numSyllables': 2}, {'word': 'clarify', 'score': 1663, 'numSyllables': 3}, {'word': 'butterfly', 'score': 1630, 'numSyllables': 3}, {'word': 'try', 'score': 1617, 'numSyllables': 1}, {'word': 'verify', 'score': 1613, 'numSyllables': 3}, {'word': 'vie', 'score': 1562, 'numSyllables': 1}, {'word': 'deny', 'score': 1556, 'numSyllables': 2}, {'word': 'rectify', 'score': 1551, 'numSyllables': 3}, {'word': 'defy', 'score': 1550, 'numSyllables': 2}, {'word': 'guy', 'score': 1528, 'numSyllables': 1}, {'word': 'y', 'score': 1497, 'numSyllables': 1}, {'word': 'sly', 'score': 1481, 'numSyllables': 1}, {'word': 'indemnify', 'score': 1455, 'numSyllables': 4}, {'word': 'dye', 'score': 1391, 'numSyllables': 1}, {'word': 'ratify', 'score': 1378, 'numSyllables': 3}, {'word': 'goodbye', 'score': 1368, 'numSyllables': 2}, {'word': 'justify', 'score': 1328, 'numSyllables': 3}, {'word': 'decry', 'score': 1298, 'numSyllables': 2}, {'word': 'rely', 'score': 1278, 'numSyllables': 2}, {'word': 'fry', 'score': 1272, 'numSyllables': 1}, {'word': 'ply', 'score': 1260, 'numSyllables': 1}, {'word': 'ai', 'score': 1236, 'numSyllables': 1}, {'word': 'why', 'score': 1214, 'numSyllables': 1}, {'word': 'exemplify', 'score': 1209, 'numSyllables': 4}, {'word': 'my', 'score': 1204, 'numSyllables': 1}, {'word': 'nigh', 'score': 1190, 'numSyllables': 1}, {'word': 'alibi', 'score': 1172, 'numSyllables': 3}, {'word': 'pi', 'score': 1148, 'numSyllables': 1}, {'word': 'thereby', 'score': 1126, 'numSyllables': 2}, {'word': 'pry', 'score': 1118, 'numSyllables': 1}, {'word': 'bae', 'score': 1114, 'numSyllables': 1}, {'word': 'chi', 'score': 1108, 'numSyllables': 1}, {'word': 'lye', 'score': 1104, 'numSyllables': 1}, {'word': 'edify', 'score': 1093, 'numSyllables': 3}, {'word': 'tai', 'score': 1089, 'numSyllables': 1}, {'word': 'qualify', 'score': 1082, 'numSyllables': 3}, {'word': 'sigh', 'score': 1065, 'numSyllables': 1}, {'word': 'aye', 'score': 1051, 'numSyllables': 1}, {'word': 'vilify', 'score': 1051, 'numSyllables': 3}, {'word': 'whereby', 'score': 1051, 'numSyllables': 2}, {'word': 'modify', 'score': 1034, 'numSyllables': 3}, {'word': 'mollify', 'score': 1004, 'numSyllables': 3}, {'word': 'specify', 'score': 1003, 'numSyllables': 3}, {'word': 'vi', 'score': 1003, 'numSyllables': 1}, {'word': 'underlie', 'score': 984, 'numSyllables': 3}, {'word': 'lanai', 'score': 964, 'numSyllables': 2}, {'word': 'satisfy', 'score': 949, 'numSyllables': 3}, {'word': 'notify', 'score': 938, 'numSyllables': 3}, {'word': 'codify', 'score': 931, 'numSyllables': 3}, {'word': 'occupy', 'score': 919, 'numSyllables': 3}, {'word': 'spy', 'score': 905, 'numSyllables': 1}, {'word': 'rye', 's ...

# %% [markdown]
# ### Note that the above code is equivalent to running https://api.datamuse.com/words?rel_rhy=bye in your browser.

# %% [markdown]
# # The Guardian API

# %%
#writing own function to query API
#https://towardsdatascience.com/discovering-powerful-data-the-guardian-news-api-into-python-for-nlp-1829b568fb0f


def query_api(tag, page, from_date, api_key):
    """
    Function to query the API for a particular tag
    returns: a response from API
    """
    response = requests.get("https://content.guardianapis.com/search?tag="
                            + tag + "&from-date=" + from_date 
                            +"&page=" + str(page) + "&page-size=200&api-key=" + api_key)
    return response

response = query_api('money/energy', '1', '2022-03-01', 'e723ffce-dfd5-427e-b9b8-779f5efedb02')
data= response.json()

# %%
data
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 897,
#   'startIndex': 1,
#   'pageSize': 200,
#   'currentPage': 1,
#   'pages': 5,
#   'orderBy': 'newest',
#   'results': [{'id': 'business/2023/mar/12/british-gas-service-arvato-made-a-third-of-all-warrant-request-to-force-fit-prepay-meters',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-03-12T16:12:04Z',
#     'webTitle': 'British Gas debt agents made third of all applications to force-fit prepay meters',
#     'webUrl': 'https://www.theguardian.com/business/2023/mar/12/british-gas-service-arvato-made-a-third-of-all-warrant-request-to-force-fit-prepay-meters',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/mar/12/british-gas-service-arvato-made-a-third-of-all-warrant-request-to-force-fit-prepay-meters',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'lifeandstyle/2023/mar/09/the-closure-of-swimming-pools-is-a-travesty',
#     'type': 'article',
#     'sectionId': 'lifeandstyle',
#     'sectionName': 'Life and style',
#     'webPublicationDate': '2023-03-09T17:47:00Z',
#     'webTitle': 'The closure of swimming pools is a travesty | Letter',
#     'webUrl': 'https://www.theguardian.com/lifeandstyle/2023/mar/09/the-closure-of-swimming-pools-is-a-travesty',
#     'apiUrl': 'https://content.guardianapis.com/lifeandstyle/2023/mar/09/the-closure-of-swimming-pools-is-a-travesty',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2023/mar/08/freezing-house-friends-homelessness-heat-or-eat',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-03-08T12:00:40Z',
#     'webTitle': 'In my freezing house, gripped by fear, I scrawl ‘things can get better’ on a chalkboard | Marin',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/mar/08/freezing-house-friends-homelessness-heat-or-eat',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/mar/08/freezing-house-friends-homelessness-heat-or-eat',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'money/2023/mar/08/energy-bills-social-tariff-martin-lewis',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-03-08T06:00:19Z',
#     'webTitle': 'Martin Lewis backs ‘social tariff’ that could cut energy bills by up to £1,500',
#     'webUrl': 'https://www.theguardian.com/money/2023/mar/08/energy-bills-social-tariff-martin-lewis',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/mar/08/energy-bills-social-tariff-martin-lewis',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'politics/2023/mar/07/grant-shapps-banned-energy-ministers-from-taking-foreign-trips',
#     'type': 'article',
#     'sectionId': 'politics',
#     'sectionName': 'Politics',
#     'webPublicationDate': '2023-03-07T19:34:05Z',
#     'webTitle': 'Grant Shapps banned energy ministers from taking foreign trips',
#     'webUrl': 'https://www.theguardian.com/politics/2023/mar/07/grant-shapps-banned-energy-ministers-from-taking-foreign-trips',
#     'apiUrl': 'https://content.guardianapis.com/politics/2023/mar/07/grant-shapps-banned-energy-ministers-from-taking-foreign-trips',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/mar/07/national-grid-power-plants-coldest-night-of-year-extra-electricity',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-03-07T16:43:37Z',
#     'webTitle': 'National Grid puts backup coal plants into action for first time this winter',
#     'webUrl': 'https://www.theguardian.com/business/2023/mar/07/national-grid-power-plants-coldest-night-of-year-extra-electricity',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/mar/07/national-grid-power-plants-coldest-night-of-year-extra-electricity',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/mar/07/state-owned-electricity-generation-firm-save-common-wealth',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-03-07T07:00:30Z',
#     'webTitle': 'State-owned electricity generation firm ‘could save Britons nearly £21bn a year’',
#     'webUrl': 'https://www.theguardian.com/business/2023/mar/07/state-owned-electricity-generation-firm-save-common-wealth',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/mar/07/state-owned-electricity-generation-firm-save-common-wealth',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/mar/06/leading-uk-ceos-attack-energy-support-policy-as-brake-on-investment',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-03-06T22:28:54Z',
#     'webTitle': 'Labour proposes long-term tax breaks to increase UK investment and growth',
#     'webUrl': 'https://www.theguardian.com/money/2023/mar/06/leading-uk-ceos-attack-energy-support-policy-as-brake-on-investment',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/mar/06/leading-uk-ceos-attack-energy-support-policy-as-brake-on-investment',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'politics/2023/mar/06/for-once-matt-hancock-speaks-for-us-all',
#     'type': 'article',
#     'sectionId': 'politics',
#     'sectionName': 'Politics',
#     'webPublicationDate': '2023-03-06T18:24:04Z',
#     'webTitle': 'For once, Matt Hancock speaks for us all | Brief letters',
#     'webUrl': 'https://www.theguardian.com/politics/2023/mar/06/for-once-matt-hancock-speaks-for-us-all',
#     'apiUrl': 'https://content.guardianapis.com/politics/2023/mar/06/for-once-matt-hancock-speaks-for-us-all',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/mar/06/yorkshire-canal-boaters-hebden-bridge-locked-fuel-support',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-03-06T09:00:22Z',
#     'webTitle': '‘Left out in the cold’: the boaters locked out of fuel support',
#     'webUrl': 'https://www.theguardian.com/business/2023/mar/06/yorkshire-canal-boaters-hebden-bridge-locked-fuel-support',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/mar/06/yorkshire-canal-boaters-hebden-bridge-locked-fuel-support',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/mar/04/solar-panels-home-batteries-save-cut-bill-costs',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-03-04T07:00:18Z',
#     'webTitle': '‘My new solar panels and batteries should save me £1,600 this year’',
#     'webUrl': 'https://www.theguardian.com/money/2023/mar/04/solar-panels-home-batteries-save-cut-bill-costs',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/mar/04/solar-panels-home-batteries-save-cut-bill-costs',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/mar/03/uk-suppliers-expect-government-u-turn-on-planned-cut-to-energy-bill-support',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-03-03T10:28:01Z',
#     'webTitle': 'UK suppliers expect government U-turn on planned cut to energy bill support',
#     'webUrl': 'https://www.theguardian.com/money/2023/mar/03/uk-suppliers-expect-government-u-turn-on-planned-cut-to-energy-bill-support',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/mar/03/uk-suppliers-expect-government-u-turn-on-planned-cut-to-energy-bill-support',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'environment/2023/mar/01/uk-efforts-to-deal-with-energy-crisis-raise-risk-of-missing-net-zero-target',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-03-01T00:01:18Z',
#     'webTitle': 'UK efforts to deal with energy crisis ‘raise risk of missing net zero target’',
#     'webUrl': 'https://www.theguardian.com/environment/2023/mar/01/uk-efforts-to-deal-with-energy-crisis-raise-risk-of-missing-net-zero-target',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/mar/01/uk-efforts-to-deal-with-energy-crisis-raise-risk-of-missing-net-zero-target',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'society/2023/feb/28/pressure-jeremy-hunt-as-2m-more-households-fall-into-fuel-poverty',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2023-02-28T17:38:51Z',
#     'webTitle': 'Pressure rises on Hunt as 2m more households fall into fuel poverty',
#     'webUrl': 'https://www.theguardian.com/society/2023/feb/28/pressure-jeremy-hunt-as-2m-more-households-fall-into-fuel-poverty',
#     'apiUrl': 'https://content.guardianapis.com/society/2023/feb/28/pressure-jeremy-hunt-as-2m-more-households-fall-into-fuel-poverty',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2023/feb/28/ministers-urban-ban-domestic-wood-burning-pollution-britain',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-28T15:34:38Z',
#     'webTitle': 'UK MPs could weigh merits of urban ban on domestic wood burning',
#     'webUrl': 'https://www.theguardian.com/environment/2023/feb/28/ministers-urban-ban-domestic-wood-burning-pollution-britain',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/feb/28/ministers-urban-ban-domestic-wood-burning-pollution-britain',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/27/uk-energy-minister-blames-labour-for-soaring-energy-bills',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-27T17:20:50Z',
#     'webTitle': 'UK energy minister blames Labour for soaring energy bills ',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/27/uk-energy-minister-blames-labour-for-soaring-energy-bills',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/27/uk-energy-minister-blames-labour-for-soaring-energy-bills',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/nils-pratley-on-finance/2023/feb/27/ministers-ssocial-tariff-energy-price-cap',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-27T16:56:43Z',
#     'webTitle': 'Ministers should stop dithering. A social tariff for energy is essential | Nils Pratley',
#     'webUrl': 'https://www.theguardian.com/business/nils-pratley-on-finance/2023/feb/27/ministers-ssocial-tariff-energy-price-cap',
#     'apiUrl': 'https://content.guardianapis.com/business/nils-pratley-on-finance/2023/feb/27/ministers-ssocial-tariff-energy-price-cap',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/27/energy-price-cap-uk-ofgem-april',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-27T16:27:58Z',
#     'webTitle': 'Pressure on Hunt as energy bills will rise despite fall in price cap',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/27/energy-price-cap-uk-ofgem-april',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/27/energy-price-cap-uk-ofgem-april',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'environment/2023/feb/27/demand-wood-burning-stoves-uk-energy-crisis',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-27T12:20:17Z',
#     'webTitle': 'Selfish or a godsend? Readers share their views on wood-burning stoves',
#     'webUrl': 'https://www.theguardian.com/environment/2023/feb/27/demand-wood-burning-stoves-uk-energy-crisis',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/feb/27/demand-wood-burning-stoves-uk-energy-crisis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/27/why-energy-bills-going-up-what-help-will-uk',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-27T09:17:02Z',
#     'webTitle': 'Why are UK energy bills going up and what help will you get?',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/27/why-energy-bills-going-up-what-help-will-uk',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/27/why-energy-bills-going-up-what-help-will-uk',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2023/feb/26/yes-we-have-no-tomatoes-why-shelves-are-emptying-in-uk-stores',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-26T06:00:13Z',
#     'webTitle': 'Yes, we have no tomatoes: Why shelves are emptying in UK stores',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/26/yes-we-have-no-tomatoes-why-shelves-are-emptying-in-uk-stores',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/26/yes-we-have-no-tomatoes-why-shelves-are-emptying-in-uk-stores',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/26/uk-cuts-back-on-cooking-sunday-roasts-as-energy-bills-soar',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-26T06:00:12Z',
#     'webTitle': 'UK cuts back on cooking Sunday roasts as energy bills soar',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/26/uk-cuts-back-on-cooking-sunday-roasts-as-energy-bills-soar',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/26/uk-cuts-back-on-cooking-sunday-roasts-as-energy-bills-soar',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/feb/25/jeremy-hunt-energy-bills-support-cut-tuc-analysis',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-25T00:01:36Z',
#     'webTitle': 'Jeremy Hunt under pressure to cancel planned cut to energy bills support',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/25/jeremy-hunt-energy-bills-support-cut-tuc-analysis',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/25/jeremy-hunt-energy-bills-support-cut-tuc-analysis',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/feb/23/ofgem-directors-prepayment-meter-scandal',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-23T16:23:02Z',
#     'webTitle': 'Ofgem board faces shake-up over handling of energy crisis',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/23/ofgem-directors-prepayment-meter-scandal',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/23/ofgem-directors-prepayment-meter-scandal',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2023/feb/23/electricity-alive-cost-of-living-crisis-disabled-government-vulnerable',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-23T12:13:44Z',
#     'webTitle': 'As a disabled person I need electricity to keep me alive. So why is it costing me so much? | Karis Williamson',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/23/electricity-alive-cost-of-living-crisis-disabled-government-vulnerable',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/23/electricity-alive-cost-of-living-crisis-disabled-government-vulnerable',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'business/2023/feb/23/we-have-to-pay-more-for-food-britains-biggest-tomato-farmer-on-the-runaway-costs-of-growing',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-23T06:00:47Z',
#     'webTitle': '‘We have to pay more for food’: Britain’s biggest tomato farmer on the runaway costs of growing',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/23/we-have-to-pay-more-for-food-britains-biggest-tomato-farmer-on-the-runaway-costs-of-growing',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/23/we-have-to-pay-more-for-food-britains-biggest-tomato-farmer-on-the-runaway-costs-of-growing',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/22/uk-inflation-could-fall-below-2-citi-forecasts',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-22T17:15:00Z',
#     'webTitle': 'UK inflation could fall below 2% this year, Citi forecasts',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/22/uk-inflation-could-fall-below-2-citi-forecasts',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/22/uk-inflation-could-fall-below-2-citi-forecasts',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/22/scottishpower-reports-retail-loss-as-consumers-cut-back-on-energy-use',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-22T12:53:16Z',
#     'webTitle': 'ScottishPower reports retail loss as consumers cut back on energy use',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/22/scottishpower-reports-retail-loss-as-consumers-cut-back-on-energy-use',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/22/scottishpower-reports-retail-loss-as-consumers-cut-back-on-energy-use',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2023/feb/22/money-worries-heat-or-eat-single-mum-care-worker',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-22T11:00:22Z',
#     'webTitle': 'I used to shoulder the money worries – now my kids feel the burden too. I chase them around the house turning off lights | Charlie',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/22/money-worries-heat-or-eat-single-mum-care-worker',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/22/money-worries-heat-or-eat-single-mum-care-worker',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'environment/2023/feb/22/450m-boiler-upgrade-scheme-failing-deliver-heating',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-22T06:00:16Z',
#     'webTitle': '£450m boiler upgrade scheme for England and Wales is failing to deliver',
#     'webUrl': 'https://www.theguardian.com/environment/2023/feb/22/450m-boiler-upgrade-scheme-failing-deliver-heating',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/feb/22/450m-boiler-upgrade-scheme-failing-deliver-heating',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/21/remove-prepayment-meters-that-were-wrongly-force-fitted-ofgem-tells-suppliers',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-21T12:52:19Z',
#     'webTitle': 'Suppliers told to remove prepayment meters that were wrongly force-fitted ',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/21/remove-prepayment-meters-that-were-wrongly-force-fitted-ofgem-tells-suppliers',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/21/remove-prepayment-meters-that-were-wrongly-force-fitted-ofgem-tells-suppliers',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'environment/2023/feb/21/britains-farmers-battered-by-brexit-fallout-and-rising-costs-says-union',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-21T06:00:06Z',
#     'webTitle': 'Britain’s farmers battered by Brexit fallout and rising costs, says union ',
#     'webUrl': 'https://www.theguardian.com/environment/2023/feb/21/britains-farmers-battered-by-brexit-fallout-and-rising-costs-says-union',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/feb/21/britains-farmers-battered-by-brexit-fallout-and-rising-costs-says-union',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/21/energy-crisis-ukraine-war-uk-cost-gas',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-21T00:01:08Z',
#     'webTitle': 'Energy crisis stemming from Ukraine war ‘cost £1k for every UK adult’',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/21/energy-crisis-ukraine-war-uk-cost-gas',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/21/energy-crisis-ukraine-war-uk-cost-gas',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/20/hit-that-switch-uk-energy-suppliers-competitive-prices',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-20T16:10:53Z',
#     'webTitle': 'Hit that switch: UK energy suppliers will get competitive again',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/20/hit-that-switch-uk-energy-suppliers-competitive-prices',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/20/hit-that-switch-uk-energy-suppliers-competitive-prices',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/feb/20/one-in-four-vouchers-for-prepayment-meters-unredeemed-in-britain',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-20T07:00:31Z',
#     'webTitle': 'One in four vouchers for prepayment meters unredeemed in Britain',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/20/one-in-four-vouchers-for-prepayment-meters-unredeemed-in-britain',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/20/one-in-four-vouchers-for-prepayment-meters-unredeemed-in-britain',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2023/feb/17/energy-sector-gas-shareholder-profits',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-17T07:00:04Z',
#     'webTitle': 'The energy sector isn’t ‘broken’, it’s cooking on gas – if you’re a profit-hungry shareholder | Mathew Lawrence',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/17/energy-sector-gas-shareholder-profits',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/17/energy-sector-gas-shareholder-profits',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'money/commentisfree/2023/feb/16/moral-questions-for-a-prepay-meter-fitter',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-16T17:43:12Z',
#     'webTitle': 'Moral questions for a prepay meter fitter | Brief letters',
#     'webUrl': 'https://www.theguardian.com/money/commentisfree/2023/feb/16/moral-questions-for-a-prepay-meter-fitter',
#     'apiUrl': 'https://content.guardianapis.com/money/commentisfree/2023/feb/16/moral-questions-for-a-prepay-meter-fitter',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'society/2023/feb/16/soaring-fuel-bills-may-push-141m-more-into-extreme-poverty-globally-study',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-16T16:00:02Z',
#     'webTitle': 'Soaring fuel bills may push 141m more into extreme poverty globally – study',
#     'webUrl': 'https://www.theguardian.com/society/2023/feb/16/soaring-fuel-bills-may-push-141m-more-into-extreme-poverty-globally-study',
#     'apiUrl': 'https://content.guardianapis.com/society/2023/feb/16/soaring-fuel-bills-may-push-141m-more-into-extreme-poverty-globally-study',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/15/ofgem-says-temporary-ban-on-forced-prepayment-meters-will-last-six-more-weeks',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-15T18:23:30Z',
#     'webTitle': 'Ofgem says ban on forced prepayment meters will end in six weeks',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/15/ofgem-says-temporary-ban-on-forced-prepayment-meters-will-last-six-more-weeks',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/15/ofgem-says-temporary-ban-on-forced-prepayment-meters-will-last-six-more-weeks',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2023/feb/12/small-victory-prepayment-meters-abolish-them-energy-companies',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-12T15:45:12Z',
#     'webTitle': 'I know the inhumanity of prepayment meters. Forget reform – they should be abolished  | Kerry Hudson',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/12/small-victory-prepayment-meters-abolish-them-energy-companies',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/12/small-victory-prepayment-meters-abolish-them-energy-companies',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'commentisfree/2023/feb/12/if-the-government-could-only-give-poorer-people-some-more-time',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-12T10:00:20Z',
#     'webTitle': 'If the government could only give poorer people some more time | Torsten Bell',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/12/if-the-government-could-only-give-poorer-people-some-more-time',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/12/if-the-government-could-only-give-poorer-people-some-more-time',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'money/2023/feb/12/home-insulation-stop-bills-through-the-roof-energy-efficiency',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-12T07:00:16Z',
#     'webTitle': 'Home insulation: how to stop your bills going through the roof',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/12/home-insulation-stop-bills-through-the-roof-energy-efficiency',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/12/home-insulation-stop-bills-through-the-roof-energy-efficiency',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'politics/live/2023/feb/10/dominic-raab-says-setting-high-standards-not-same-as-bullying-as-he-sidesteps-resignation-question-uk-politics-live',
#     'type': 'liveblog',
#     'sectionId': 'politics',
#     'sectionName': 'Politics',
#     'webPublicationDate': '2023-02-10T17:06:06Z',
#     'webTitle': 'RMT strikes to continue, says Mick Lynch, after members reject ‘dreadful’ pay offers – as it happened',
#     'webUrl': 'https://www.theguardian.com/politics/live/2023/feb/10/dominic-raab-says-setting-high-standards-not-same-as-bullying-as-he-sidesteps-resignation-question-uk-politics-live',
#     'apiUrl': 'https://content.guardianapis.com/politics/live/2023/feb/10/dominic-raab-says-setting-high-standards-not-same-as-bullying-as-he-sidesteps-resignation-question-uk-politics-live',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/10/uk-energy-suppliers-to-end-prepayment-meter-installation-in-vulnerable-homes',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-10T10:25:51Z',
#     'webTitle': 'UK energy suppliers to end prepayment meter installation in vulnerable homes',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/10/uk-energy-suppliers-to-end-prepayment-meter-installation-in-vulnerable-homes',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/10/uk-energy-suppliers-to-end-prepayment-meter-installation-in-vulnerable-homes',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/10/stab-vests-huge-dogs-and-escape-routes-british-gas-prepay-meter-fitter',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-10T10:00:04Z',
#     'webTitle': 'Stab vests, huge dogs and escape routes: the secret diary of a prepay meter fitter',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/10/stab-vests-huge-dogs-and-escape-routes-british-gas-prepay-meter-fitter',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/10/stab-vests-huge-dogs-and-escape-routes-british-gas-prepay-meter-fitter',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2023/feb/09/act-now-energy-bills-subsidy-fuel-poverty-martin-lewis',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-09T06:00:15Z',
#     'webTitle': 'Act now on energy bills subsidy or see fuel poverty surge, says Martin Lewis',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/09/act-now-energy-bills-subsidy-fuel-poverty-martin-lewis',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/09/act-now-energy-bills-subsidy-fuel-poverty-martin-lewis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'society/2023/feb/09/greenpeace-threatens-legal-action-over-uk-failure-to-meet-fuel-poverty-targets',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2023-02-09T00:01:09Z',
#     'webTitle': 'Greenpeace threatens legal action over UK failure to meet fuel poverty targets',
#     'webUrl': 'https://www.theguardian.com/society/2023/feb/09/greenpeace-threatens-legal-action-over-uk-failure-to-meet-fuel-poverty-targets',
#     'apiUrl': 'https://content.guardianapis.com/society/2023/feb/09/greenpeace-threatens-legal-action-over-uk-failure-to-meet-fuel-poverty-targets',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/07/low-income-households-miss-out-on-50m-to-help-pay-energy-bills',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-07T18:47:39Z',
#     'webTitle': 'Low income households miss out on £50m to help pay energy bills',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/07/low-income-households-miss-out-on-50m-to-help-pay-energy-bills',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/07/low-income-households-miss-out-on-50m-to-help-pay-energy-bills',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/07/energy-bills-british-households-help-nao',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-07T06:00:14Z',
#     'webTitle': 'Energy bills: ‘significant number’ of Britons got help they didn’t need – NAO',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/07/energy-bills-british-households-help-nao',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/07/energy-bills-british-households-help-nao',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'politics/live/2023/feb/06/nhs-strikes-nurses-ambulance-workers-government-union-pay-negotiations-conservatives-rishi-sunak-uk-politics-latest',
#     'type': 'liveblog',
#     'sectionId': 'politics',
#     'sectionName': 'Politics',
#     'webPublicationDate': '2023-02-06T18:02:17Z',
#     'webTitle': 'Liz Truss says it is ‘unfair’ to blame her mini-budget for interest rate hike and rules out being PM again – as it happened',
#     'webUrl': 'https://www.theguardian.com/politics/live/2023/feb/06/nhs-strikes-nurses-ambulance-workers-government-union-pay-negotiations-conservatives-rishi-sunak-uk-politics-latest',
#     'apiUrl': 'https://content.guardianapis.com/politics/live/2023/feb/06/nhs-strikes-nurses-ambulance-workers-government-union-pay-negotiations-conservatives-rishi-sunak-uk-politics-latest',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/06/prepayment-meters-forced-installations-england-wales',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-06T17:53:49Z',
#     'webTitle': 'Prepayment meters: magistrates told to stop allowing forced installations ',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/06/prepayment-meters-forced-installations-england-wales',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/06/prepayment-meters-forced-installations-england-wales',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'politics/2023/feb/06/brave-civil-service-whistleblowers-give-us-hope',
#     'type': 'article',
#     'sectionId': 'politics',
#     'sectionName': 'Politics',
#     'webPublicationDate': '2023-02-06T16:46:19Z',
#     'webTitle': 'Brave civil service whistleblowers give us hope for public life | Brief letters',
#     'webUrl': 'https://www.theguardian.com/politics/2023/feb/06/brave-civil-service-whistleblowers-give-us-hope',
#     'apiUrl': 'https://content.guardianapis.com/politics/2023/feb/06/brave-civil-service-whistleblowers-give-us-hope',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/06/fixed-price-energy-customers-face-bill-shock-as-standing-charges-soar',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-06T09:00:16Z',
#     'webTitle': 'Fixed-price energy customers face bill shock as standing charges soar',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/06/fixed-price-energy-customers-face-bill-shock-as-standing-charges-soar',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/06/fixed-price-energy-customers-face-bill-shock-as-standing-charges-soar',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/feb/05/grant-shapps-sitting-on-hands-amid-prepayment-meter-scandal-says-labour',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-05T20:00:30Z',
#     'webTitle': 'Grant Shapps ‘sitting on hands’ amid prepayment meter scandal, says Labour',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/05/grant-shapps-sitting-on-hands-amid-prepayment-meter-scandal-says-labour',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/05/grant-shapps-sitting-on-hands-amid-prepayment-meter-scandal-says-labour',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2023/feb/05/british-gas-is-ready-to-bully-beyond-the-grave',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-05T17:21:52Z',
#     'webTitle': 'British Gas is ready to bully beyond the grave | Brief letters',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/05/british-gas-is-ready-to-bully-beyond-the-grave',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/05/british-gas-is-ready-to-bully-beyond-the-grave',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/05/billionaire-investor-kretinsky-and-trader-vitol-eye-fortune-in-british-power-plant-subsidies',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-05T16:00:25Z',
#     'webTitle': 'Billionaire investor Křetínský and trader Vitol eye fortune in British power plant subsidies',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/05/billionaire-investor-kretinsky-and-trader-vitol-eye-fortune-in-british-power-plant-subsidies',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/05/billionaire-investor-kretinsky-and-trader-vitol-eye-fortune-in-british-power-plant-subsidies',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/feb/05/energy-prices-to-soar-again-as-jeremy-hunt-rejects-pleas-to-halt-rise',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-02-05T09:00:16Z',
#     'webTitle': 'Energy prices to soar again as Jeremy Hunt rejects pleas to halt rise',
#     'webUrl': 'https://www.theguardian.com/money/2023/feb/05/energy-prices-to-soar-again-as-jeremy-hunt-rejects-pleas-to-halt-rise',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/feb/05/energy-prices-to-soar-again-as-jeremy-hunt-rejects-pleas-to-halt-rise',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2023/feb/05/the-observer-view-on-the-shameful-premium-that-the-poorest-pay-for-their-energy',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-05T06:30:13Z',
#     'webTitle': 'The Observer view on the shameful premium that the poorest pay for their energy | Observer editorial',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/05/the-observer-view-on-the-shameful-premium-that-the-poorest-pay-for-their-energy',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/05/the-observer-view-on-the-shameful-premium-that-the-poorest-pay-for-their-energy',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'environment/2023/feb/04/alternative-wood-burning-stove-climate',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2023-02-04T07:00:25Z',
#     'webTitle': 'What is the best alternative to a wood-burning stove?',
#     'webUrl': 'https://www.theguardian.com/environment/2023/feb/04/alternative-wood-burning-stove-climate',
#     'apiUrl': 'https://content.guardianapis.com/environment/2023/feb/04/alternative-wood-burning-stove-climate',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2023/feb/03/british-gas-bailiffs-meters-poor-people-electricity',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-03T14:18:08Z',
#     'webTitle': '‘It’s not who we are,’ wails British Gas. Sorry but when you’re using bailiffs to install meters, that’s exactly who you are | Marina Hyde',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/03/british-gas-bailiffs-meters-poor-people-electricity',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/03/british-gas-bailiffs-meters-poor-people-electricity',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'business/2023/feb/02/watchdog-urges-uk-energy-suppliers-to-use-only-accredited-bailiffs',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-02T22:15:23Z',
#     'webTitle': 'Ofgem warns suppliers over forcible installation of prepayment meters',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/02/watchdog-urges-uk-energy-suppliers-to-use-only-accredited-bailiffs',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/02/watchdog-urges-uk-energy-suppliers-to-use-only-accredited-bailiffs',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2023/feb/02/energy-profits-british-gas-prepayment-meters-scandal',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2023-02-02T17:27:16Z',
#     'webTitle': 'Energy bailiffs for the poorest, huge profits for the richest: this is Britain in 2023 | Gaby Hinsliff',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2023/feb/02/energy-profits-british-gas-prepayment-meters-scandal',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2023/feb/02/energy-profits-british-gas-prepayment-meters-scandal',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'business/2023/feb/02/energy-regulator-launches-british-gas-investigation-over-prepayment-meters',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-02T10:28:16Z',
#     'webTitle': 'Energy regulator launches British Gas investigation over prepayment meters',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/02/energy-regulator-launches-british-gas-investigation-over-prepayment-meters',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/02/energy-regulator-launches-british-gas-investigation-over-prepayment-meters',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/01/british-gas-halts-use-of-warrants-to-force-people-on-to-prepayment-meters-allegations-vulnerable-customers-break-in',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-01T19:13:16Z',
#     'webTitle': 'British Gas halts use of warrants to force people on to prepayment meters',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/01/british-gas-halts-use-of-warrants-to-force-people-on-to-prepayment-meters-allegations-vulnerable-customers-break-in',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/01/british-gas-halts-use-of-warrants-to-force-people-on-to-prepayment-meters-allegations-vulnerable-customers-break-in',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/feb/01/octopus-says-it-chose-to-ditch-profit-to-keep-energy-bills-down',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-02-01T11:11:50Z',
#     'webTitle': 'Octopus says it chose to ditch profit to keep energy bills down',
#     'webUrl': 'https://www.theguardian.com/business/2023/feb/01/octopus-says-it-chose-to-ditch-profit-to-keep-energy-bills-down',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/feb/01/octopus-says-it-chose-to-ditch-profit-to-keep-energy-bills-down',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/jan/31/paying-smart-meter-owners-to-use-less-electricity-may-harm-poor-peoples-health',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-01-31T18:24:14Z',
#     'webTitle': 'Paying smart meter owners to use less electricity may harm poor people’s health | Letters ',
#     'webUrl': 'https://www.theguardian.com/money/2023/jan/31/paying-smart-meter-owners-to-use-less-electricity-may-harm-poor-peoples-health',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/jan/31/paying-smart-meter-owners-to-use-less-electricity-may-harm-poor-peoples-health',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2023/jan/31/ofgem-considers-subsidy-level-energy-costs-prepayment-direct-debit',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-01-31T16:13:28Z',
#     'webTitle': 'Ofgem considers subsidy to level energy costs for prepayment and direct debit customers',
#     'webUrl': 'https://www.theguardian.com/business/2023/jan/31/ofgem-considers-subsidy-level-energy-costs-prepayment-direct-debit',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/jan/31/ofgem-considers-subsidy-level-energy-costs-prepayment-direct-debit',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2023/jan/27/octopus-energy-court-british-gas-eon-scottish-power-bulb',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2023-01-27T16:55:55Z',
#     'webTitle': 'Octopus Energy calls rivals ‘desperate’ in bitter court clash',
#     'webUrl': 'https://www.theguardian.com/business/2023/jan/27/octopus-energy-court-british-gas-eon-scottish-power-bulb',
#     'apiUrl': 'https://content.guardianapis.com/business/2023/jan/27/octopus-energy-court-british-gas-eon-scottish-power-bulb',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2023/jan/26/why-cant-avantigas-deliver-were-about-to-run-out-of-fuel',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-01-26T07:00:52Z',
#     'webTitle': 'Why can’t AvantiGas deliver? We’re about to run out of fuel',
#     'webUrl': 'https://www.theguardian.com/money/2023/jan/26/why-cant-avantigas-deliver-were-about-to-run-out-of-fuel',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/jan/26/why-cant-avantigas-deliver-were-about-to-run-out-of-fuel',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/jan/25/1m-paid-to-octopus-energy-customers-as-part-of-power-saving-scheme',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-01-25T22:36:51Z',
#     'webTitle': '£1m paid to Octopus Energy customers as part of power saving scheme',
#     'webUrl': 'https://www.theguardian.com/money/2023/jan/25/1m-paid-to-octopus-energy-customers-as-part-of-power-saving-scheme',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/jan/25/1m-paid-to-octopus-energy-customers-as-part-of-power-saving-scheme',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2023/jan/25/bulb-energys-billing-errors-plunged-my-family-into-penury',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2023-01-25T07:00:14Z',
#     'webTitle': 'Bulb energy’s billing errors plunged my family into penury ',
#     'webUrl': 'https://www.theguardian.com/money/2023/jan/25/bulb-energys-billing-errors-plunged-my-family-into-penury',
#     'apiUrl': 'https://content.guardianapis.com/money/2023/jan/25/bulb-energys-billing-errors-plunged-my-family-into-penury',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
# ...
#     'apiUrl': 'https://content.guardianapis.com/business/2022/dec/02/half-a-million-vulnerable-households-miss-out-on-help-with-energy-bills',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2022/dec/01/my-hands-are-frozen-as-i-type-we-are-existing-not-living',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2022-12-01T18:28:14Z',
#     'webTitle': 'My hands are frozen as I type – we are existing, not living | Letter',
#     'webUrl': 'https://www.theguardian.com/money/2022/dec/01/my-hands-are-frozen-as-i-type-we-are-existing-not-living',
#     'apiUrl': 'https://content.guardianapis.com/money/2022/dec/01/my-hands-are-frozen-as-i-type-we-are-existing-not-living',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'money/2022/nov/30/losing-energy-support-will-mean-fuel-poverty-for-more-than-7m-in-uk',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2022-11-30T22:00:28Z',
#     'webTitle': 'Losing energy support will mean ‘fuel poverty for more than 7m’ in UK',
#     'webUrl': 'https://www.theguardian.com/money/2022/nov/30/losing-energy-support-will-mean-fuel-poverty-for-more-than-7m-in-uk',
#     'apiUrl': 'https://content.guardianapis.com/money/2022/nov/30/losing-energy-support-will-mean-fuel-poverty-for-more-than-7m-in-uk',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2022/nov/30/uk-food-price-inflation-hits-new-high-of-124',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-30T00:01:01Z',
#     'webTitle': 'UK food price inflation hits new high of 12.4% ',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/30/uk-food-price-inflation-hits-new-high-of-124',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/30/uk-food-price-inflation-hits-new-high-of-124',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/29/octopus-takeover-of-bulb-faces-delay-after-rivals-seek-judicial-review',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-29T18:34:23Z',
#     'webTitle': 'Octopus takeover of Bulb faces delay after rivals seek judicial review',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/29/octopus-takeover-of-bulb-faces-delay-after-rivals-seek-judicial-review',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/29/octopus-takeover-of-bulb-faces-delay-after-rivals-seek-judicial-review',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2022/nov/29/high-energy-bills-electricity-disabled-person-ventilator-die',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2022-11-29T08:00:21Z',
#     'webTitle': 'Disabled children can’t afford to use their ventilators this winter. Politicians need to face reality | Frances Ryan',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2022/nov/29/high-energy-bills-electricity-disabled-person-ventilator-die',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2022/nov/29/high-energy-bills-electricity-disabled-person-ventilator-die',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'society/2022/nov/29/calls-for-uk-ban-on-pre-payment-meter-installations-made-under-court-warrants',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2022-11-29T00:01:11Z',
#     'webTitle': 'Calls for UK ban on pre-payment meter installations made under court warrants',
#     'webUrl': 'https://www.theguardian.com/society/2022/nov/29/calls-for-uk-ban-on-pre-payment-meter-installations-made-under-court-warrants',
#     'apiUrl': 'https://content.guardianapis.com/society/2022/nov/29/calls-for-uk-ban-on-pre-payment-meter-installations-made-under-court-warrants',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/28/national-grid-emergency-winter-plan-energy-prices',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-28T15:41:35Z',
#     'webTitle': 'National Grid cancels plans to start emergency winter scheme',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/28/national-grid-emergency-winter-plan-energy-prices',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/28/national-grid-emergency-winter-plan-energy-prices',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2022/nov/27/uk-households-have-cut-energy-consumption-by-10-say-suppliers',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2022-11-27T15:30:08Z',
#     'webTitle': 'UK households have cut energy consumption by 10%, say suppliers',
#     'webUrl': 'https://www.theguardian.com/money/2022/nov/27/uk-households-have-cut-energy-consumption-by-10-say-suppliers',
#     'apiUrl': 'https://content.guardianapis.com/money/2022/nov/27/uk-households-have-cut-energy-consumption-by-10-say-suppliers',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'commentisfree/2022/nov/27/observer-view-fuel-poverty-lowest-paid-freezing-government-support',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2022-11-27T09:04:00Z',
#     'webTitle': 'The Observer view on fuel poverty measures freezing out poorest Britons | Observer editorial',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2022/nov/27/observer-view-fuel-poverty-lowest-paid-freezing-government-support',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2022/nov/27/observer-view-fuel-poverty-lowest-paid-freezing-government-support',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'society/2022/nov/27/millions-of-households-will-be-spending-nearly-third-of-income-on-fuel-by-spring',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2022-11-27T06:00:13Z',
#     'webTitle': 'Millions of households will be spending nearly third of income on fuel by spring',
#     'webUrl': 'https://www.theguardian.com/society/2022/nov/27/millions-of-households-will-be-spending-nearly-third-of-income-on-fuel-by-spring',
#     'apiUrl': 'https://content.guardianapis.com/society/2022/nov/27/millions-of-households-will-be-spending-nearly-third-of-income-on-fuel-by-spring',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/26/the-christmas-show-must-go-on-householders-vow-to-keep-the-festive-lights-on',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-26T12:00:25Z',
#     'webTitle': 'The Christmas show must go on: householders vow to keep the festive lights on ',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/26/the-christmas-show-must-go-on-householders-vow-to-keep-the-festive-lights-on',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/26/the-christmas-show-must-go-on-householders-vow-to-keep-the-festive-lights-on',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/25/ofgem-energy-rules-fail-to-protect-customer-deposits-credit-balances',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-25T08:29:43Z',
#     'webTitle': 'Ofgem unveils new energy rules but ‘fails to protect’ customer deposits',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/25/ofgem-energy-rules-fail-to-protect-customer-deposits-credit-balances',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/25/ofgem-energy-rules-fail-to-protect-customer-deposits-credit-balances',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/24/how-uk-government-plans-to-advise-households-to-reduce-energy-bills',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-24T15:59:12Z',
#     'webTitle': 'How UK government plans to advise households to reduce energy bills',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/24/how-uk-government-plans-to-advise-households-to-reduce-energy-bills',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/24/how-uk-government-plans-to-advise-households-to-reduce-energy-bills',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2022/nov/24/annual-uk-energy-bills-would-have-hit-4279-without-emergency-support-ofgem-says',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-24T14:03:53Z',
#     'webTitle': 'Britons told how to save energy as government aid bill could hit £5bn a month',
#     'webUrl': 'https://www.theguardian.com/money/2022/nov/24/annual-uk-energy-bills-would-have-hit-4279-without-emergency-support-ofgem-says',
#     'apiUrl': 'https://content.guardianapis.com/money/2022/nov/24/annual-uk-energy-bills-would-have-hit-4279-without-emergency-support-ofgem-says',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/24/sales-boost-b-and-q-screwfix-owner-kingfisher-energy-saving-products',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-24T08:52:21Z',
#     'webTitle': 'Sales boost for B&Q and Screwfix owner amid rush for energy-saving products',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/24/sales-boost-b-and-q-screwfix-owner-kingfisher-energy-saving-products',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/24/sales-boost-b-and-q-screwfix-owner-kingfisher-energy-saving-products',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'money/2022/nov/23/uk-energy-customers-bills-ovo-sse',
#     'type': 'article',
#     'sectionId': 'money',
#     'sectionName': 'Money',
#     'webPublicationDate': '2022-11-23T06:00:52Z',
#     'webTitle': 'UK energy customers receiving bills of up to £49,000 after Ovo takeover of SSE',
#     'webUrl': 'https://www.theguardian.com/money/2022/nov/23/uk-energy-customers-bills-ovo-sse',
#     'apiUrl': 'https://content.guardianapis.com/money/2022/nov/23/uk-energy-customers-bills-ovo-sse',
#     'isHosted': False,
#     'pillarId': 'pillar/lifestyle',
#     'pillarName': 'Lifestyle'},
#    {'id': 'business/2022/nov/23/im-knackered-people-forced-to-take-second-jobs-amid-cost-of-living-crisis',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-23T06:00:52Z',
#     'webTitle': '‘I’m knackered’: people forced to take second jobs amid cost of living crisis',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/23/im-knackered-people-forced-to-take-second-jobs-amid-cost-of-living-crisis',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/23/im-knackered-people-forced-to-take-second-jobs-amid-cost-of-living-crisis',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/22/severely-ill-refusing-sicknotes-as-they-cannot-afford-not-to-work-says-gps-head',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2022-11-23T00:38:25Z',
#     'webTitle': 'Severely ill refusing sicknotes as they cannot afford time off, says GPs’ head',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/22/severely-ill-refusing-sicknotes-as-they-cannot-afford-not-to-work-says-gps-head',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/22/severely-ill-refusing-sicknotes-as-they-cannot-afford-not-to-work-says-gps-head',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/22/uk-energy-suppliers-vulnerable-customers-ofgem',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-22T09:30:54Z',
#     'webTitle': 'UK energy suppliers are failing vulnerable customers, says Ofgem',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/22/uk-energy-suppliers-vulnerable-customers-ofgem',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/22/uk-energy-suppliers-vulnerable-customers-ofgem',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2022/nov/20/not-every-poor-person-is-on-benefits-so-where-is-their-lump-sum-for-energy-bills',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2022-11-20T10:30:23Z',
#     'webTitle': 'Not every poor person is on benefits, so where’s their lump sum for energy bills? | Torsten Bell',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2022/nov/20/not-every-poor-person-is-on-benefits-so-where-is-their-lump-sum-for-energy-bills',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2022/nov/20/not-every-poor-person-is-on-benefits-so-where-is-their-lump-sum-for-energy-bills',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'business/2022/nov/19/uks-most-vulnerable-missing-out-on-energy-bill-support-due-to-confusing-systems',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-19T15:57:09Z',
#     'webTitle': 'UK’s most vulnerable missing out on energy bill support due to confusing systems',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/19/uks-most-vulnerable-missing-out-on-energy-bill-support-due-to-confusing-systems',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/19/uks-most-vulnerable-missing-out-on-energy-bill-support-due-to-confusing-systems',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2022/nov/19/cost-of-living-crisis-lodger-bills-renting-out-room-home',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2022-11-19T10:00:54Z',
#     'webTitle': 'Cost of living crisis: could taking in a lodger help you pay your bills?',
#     'webUrl': 'https://www.theguardian.com/business/2022/nov/19/cost-of-living-crisis-lodger-bills-renting-out-room-home',
#     'apiUrl': 'https://content.guardianapis.com/business/2022/nov/19/cost-of-living-crisis-lodger-bills-renting-out-room-home',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'uk-news/2022/nov/17/biggest-hit-to-living-standards-on-record-as-jeremy-hunt-lays-out-autumn-statement',
#     'type': 'article',
#     'sectionId': 'uk-news',
#     'sectionName': 'UK news',
#     'webPublicationDate': '2022-11-17T20:15:50Z',
#     'webTitle': 'Biggest hit to living standards on record as Hunt lays out autumn statement',
#     'webUrl': 'https://www.theguardian.com/uk-news/2022/nov/17/biggest-hit-to-living-standards-on-record-as-jeremy-hunt-lays-out-autumn-statement',
#     'apiUrl': 'https://content.guardianapis.com/uk-news/2022/nov/17/biggest-hit-to-living-standards-on-record-as-jeremy-hunt-lays-out-autumn-statement',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'}]}}

# %%
#How do we get the data structured?

# %% [markdown]
# # Working with text

# %%
#recap - operations on strings

text = '  People who are allergic to cats are actually allergic to cat saliva or to cat dander.  \n If the resident cat is bathed regularly the allergic people tolerate it better.'
print(text)

#What do we need to do?
# Out:
#   People who are allergic to cats are actually allergic to cat saliva or to cat dander.
#  If the resident cat is bathed regularly the allergic people tolerate it better.

# %%
# processing a larger amount of data - df with articles

# %%
# writing functions with strings
